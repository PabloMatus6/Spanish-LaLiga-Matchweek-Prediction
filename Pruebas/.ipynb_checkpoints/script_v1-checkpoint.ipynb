# %%
import pandas as pd
import numpy as np
import os
import json
import requests

# %%
endpoint_url = "https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchsday&date=2021-2-28&top=1"

# %%
response = requests.get(endpoint_url)

# %%
result = json.loads(response.content)

# %%
result
# Out:
# {'matches': [{'id': '89786',
#    'round': '25',
#    'local': 'Celta',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Real Valladolid',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380741',
#    'team2': '6380750',
#    'dteam1': '712',
#    'dteam2': '2654',
#    'local_abbr': 'CEL',
#    'visitor_abbr': 'VAD',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '91.500',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/712.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2654.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '14',
#    'minute': '00',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '89792',
#    'round': '25',
#    'local': 'Cádiz',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Real Betis',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380735',
#    'team2': '6380748',
#    'dteam1': '603',
#    'dteam2': '486',
#    'local_abbr': 'CAD',
#    'visitor_abbr': 'BET',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '91.500',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/603.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/486.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '16',
#    'minute': '15',
#    'result': '0-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6380748',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '89793',
#    'round': '25',
#    'local': 'Granada',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Elche',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380744',
#    'team2': '6391867',
#    'dteam1': '4235',
#    'dteam2': '975',
#    'local_abbr': 'GRA',
#    'visitor_abbr': 'ELC',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '91.500',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/4235.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/975.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '18',
#    'minute': '30',
#    'result': '2-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6380744',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '89802',
#    'round': '25',
#    'local': 'Villarreal',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Atlético',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380753',
#    'team2': '6380739',
#    'dteam1': '2716',
#    'dteam2': '369',
#    'local_abbr': 'VIL',
#    'visitor_abbr': 'ATM',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '91.500',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2716.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/369.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '21',
#    'minute': '00',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6380739',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '72487',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Leicester',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Arsenal',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382967',
#    'team2': '6382960',
#    'dteam1': '1538',
#    'dteam2': '263',
#    'local_abbr': 'LEI',
#    'visitor_abbr': 'ARS',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '89.092',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1538.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/263.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '13',
#    'minute': '00',
#    'result': '1-3',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382960',
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72484',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Crystal Palace',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Fulham',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382965',
#    'team2': '6389128',
#    'dteam1': '860',
#    'dteam2': '1183',
#    'local_abbr': 'CRY',
#    'visitor_abbr': 'FUL',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '89.092',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/860.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1183.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '13',
#    'minute': '00',
#    'result': '0-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72491',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Tottenham Hotspur',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Burnley',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382974',
#    'team2': '6382963',
#    'dteam1': '2523',
#    'dteam2': '569',
#    'local_abbr': 'TOT',
#    'visitor_abbr': 'BUR',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '89.092',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2523.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/569.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '15',
#    'minute': '00',
#    'result': '4-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382974',
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72483',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Chelsea',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Man. Utd',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382964',
#    'team2': '6382970',
#    'dteam1': '752',
#    'dteam2': '1635',
#    'local_abbr': 'CHL',
#    'visitor_abbr': 'MUD',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '89.092',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/752.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1635.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '17',
#    'minute': '30',
#    'result': '0-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72490',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Sheffield United',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Liverpool',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382972',
#    'team2': '6382968',
#    'dteam1': '9182',
#    'dteam2': '3845',
#    'local_abbr': 'SHE',
#    'visitor_abbr': 'LIV',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '89.092',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/9182.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/3845.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '20',
#    'minute': '15',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382968',
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '90633',
#    'round': '27',
#    'local': 'Fuenlabrada',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Girona',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6387869',
#    'team2': '6391868',
#    'dteam1': '1179',
#    'dteam2': '1236',
#    'local_abbr': 'FUE',
#    'visitor_abbr': 'GIR',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '70.641',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1179.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1236.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '14',
#    'minute': '00',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '90634',
#    'round': '27',
#    'local': 'Real Sporting',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Espanyol',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382800',
#    'team2': '6382789',
#    'dteam1': '2125',
#    'dteam2': '998',
#    'local_abbr': 'SPO',
#    'visitor_abbr': 'ESP',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '70.641',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2125.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/998.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '16',
#    'minute': '00',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '303',
#      'name': '#Vamos',
#      'image': 'https://thumb.resfu.com/media/televisiones/303.png?size=50x'},
#     {'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '90639',
#    'round': '27',
#    'local': 'Tenerife',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Alcorcón',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382801',
#    'team2': '6382786',
#    'dteam1': '2477',
#    'dteam2': '64',
#    'local_abbr': 'CDT',
#    'visitor_abbr': 'ALC',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '70.641',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2477.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/64.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '18',
#    'minute': '15',
#    'result': '3-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382801',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '90637',
#    'round': '27',
#    'local': 'Real Oviedo',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Real Zaragoza',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382799',
#    'team2': '6390092',
#    'dteam1': '2115',
#    'dteam2': '2136',
#    'local_abbr': 'ROV',
#    'visitor_abbr': 'ZAR',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '70.641',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 1 mes',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2115.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2136.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '21',
#    'minute': '00',
#    'result': '1-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382799',
#    'channels': [{'id': '20',
#      'name': 'Gol',
#      'image': 'https://thumb.resfu.com/media/televisiones/20.png?size=50x'},
#     {'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]}],
#  'summary': {'today': '219', 'spain': '4', 'live': '0'}}

# %%
result['matches']
# Out:
# [{'id': '89786',
#   'round': '25',
#   'local': 'Celta',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Real Valladolid',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380741',
#   'team2': '6380750',
#   'dteam1': '712',
#   'dteam2': '2654',
#   'local_abbr': 'CEL',
#   'visitor_abbr': 'VAD',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '91.500',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/712.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2654.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '14',
#   'minute': '00',
#   'result': '1-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '89792',
#   'round': '25',
#   'local': 'Cádiz',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Real Betis',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380735',
#   'team2': '6380748',
#   'dteam1': '603',
#   'dteam2': '486',
#   'local_abbr': 'CAD',
#   'visitor_abbr': 'BET',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '91.500',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/603.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/486.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '16',
#   'minute': '15',
#   'result': '0-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6380748',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '89793',
#   'round': '25',
#   'local': 'Granada',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Elche',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380744',
#   'team2': '6391867',
#   'dteam1': '4235',
#   'dteam2': '975',
#   'local_abbr': 'GRA',
#   'visitor_abbr': 'ELC',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '91.500',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/4235.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/975.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '18',
#   'minute': '30',
#   'result': '2-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6380744',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '89802',
#   'round': '25',
#   'local': 'Villarreal',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Atlético',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380753',
#   'team2': '6380739',
#   'dteam1': '2716',
#   'dteam2': '369',
#   'local_abbr': 'VIL',
#   'visitor_abbr': 'ATM',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '91.500',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2716.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/369.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '21',
#   'minute': '00',
#   'result': '0-2',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6380739',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '72487',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Leicester',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Arsenal',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382967',
#   'team2': '6382960',
#   'dteam1': '1538',
#   'dteam2': '263',
#   'local_abbr': 'LEI',
#   'visitor_abbr': 'ARS',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '89.092',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1538.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/263.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '13',
#   'minute': '00',
#   'result': '1-3',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382960',
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72484',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Crystal Palace',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Fulham',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382965',
#   'team2': '6389128',
#   'dteam1': '860',
#   'dteam2': '1183',
#   'local_abbr': 'CRY',
#   'visitor_abbr': 'FUL',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '89.092',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/860.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1183.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '13',
#   'minute': '00',
#   'result': '0-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72491',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Tottenham Hotspur',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Burnley',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382974',
#   'team2': '6382963',
#   'dteam1': '2523',
#   'dteam2': '569',
#   'local_abbr': 'TOT',
#   'visitor_abbr': 'BUR',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '89.092',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2523.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/569.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '15',
#   'minute': '00',
#   'result': '4-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382974',
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72483',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Chelsea',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Man. Utd',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382964',
#   'team2': '6382970',
#   'dteam1': '752',
#   'dteam2': '1635',
#   'local_abbr': 'CHL',
#   'visitor_abbr': 'MUD',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '89.092',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/752.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1635.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '17',
#   'minute': '30',
#   'result': '0-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72490',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Sheffield United',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Liverpool',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382972',
#   'team2': '6382968',
#   'dteam1': '9182',
#   'dteam2': '3845',
#   'local_abbr': 'SHE',
#   'visitor_abbr': 'LIV',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '89.092',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/9182.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/3845.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '20',
#   'minute': '15',
#   'result': '0-2',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382968',
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '90633',
#   'round': '27',
#   'local': 'Fuenlabrada',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Girona',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6387869',
#   'team2': '6391868',
#   'dteam1': '1179',
#   'dteam2': '1236',
#   'local_abbr': 'FUE',
#   'visitor_abbr': 'GIR',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '70.641',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1179.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1236.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '14',
#   'minute': '00',
#   'result': '1-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '90634',
#   'round': '27',
#   'local': 'Real Sporting',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Espanyol',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382800',
#   'team2': '6382789',
#   'dteam1': '2125',
#   'dteam2': '998',
#   'local_abbr': 'SPO',
#   'visitor_abbr': 'ESP',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '70.641',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2125.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/998.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '16',
#   'minute': '00',
#   'result': '1-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '303',
#     'name': '#Vamos',
#     'image': 'https://thumb.resfu.com/media/televisiones/303.png?size=50x'},
#    {'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '90639',
#   'round': '27',
#   'local': 'Tenerife',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Alcorcón',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382801',
#   'team2': '6382786',
#   'dteam1': '2477',
#   'dteam2': '64',
#   'local_abbr': 'CDT',
#   'visitor_abbr': 'ALC',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '70.641',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2477.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/64.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '18',
#   'minute': '15',
#   'result': '3-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382801',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '90637',
#   'round': '27',
#   'local': 'Real Oviedo',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Real Zaragoza',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382799',
#   'team2': '6390092',
#   'dteam1': '2115',
#   'dteam2': '2136',
#   'local_abbr': 'ROV',
#   'visitor_abbr': 'ZAR',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '70.641',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 1 mes',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2115.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2136.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '21',
#   'minute': '00',
#   'result': '1-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382799',
#   'channels': [{'id': '20',
#     'name': 'Gol',
#     'image': 'https://thumb.resfu.com/media/televisiones/20.png?size=50x'},
#    {'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]}]

# %%
df = pd.DataFrame(result['matches'])

# %%
df['score_local'] = df['result'].apply(lambda x: x.split("-")[0])
df['score_visitor'] = df['result'].apply(lambda x: x.split("-")[1])

# %%
df.head()
# Out:
#       id round       local group_code total_group          visitor  \
# 0  89786    25       Celta          1           1  Real Valladolid
# 1  89792    25       Cádiz          1           1       Real Betis
# 2  89793    25     Granada          1           1            Elche
# 3  89802    25  Villarreal          1           1         Atlético
# 4  72487    26   Leicester          1           1          Arsenal
#
#    competition_name league_id extraName conference  ... minute result  \
# 0  Primera División     57041                    0  ...     00    1-1
# 1  Primera División     57041                    0  ...     15    0-1
# 2  Primera División     57041                    0  ...     30    2-1
# 3  Primera División     57041                    0  ...     00    0-2
# 4    Premier League     57338                    0  ...     00    1-3
#
#   live_minute status   winner  \
# 0                  1        0
# 1                  1  6380748
# 2                  1  6380744
# 3                  1  6380739
# 4                  1  6382960
#
#                                             channels isVideo numVideos  \
# 0  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 2  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 3  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 4  [{'id': '317', 'name': 'DAZN', 'image': 'https...     0.0       0.0
#
#   score_local score_visitor
# 0           1             1
# 1           0             1
# 2           2             1
# 3           0             2
# 4           1             3
#
# [5 rows x 41 columns]

# %% [markdown]
# # Peticion Por Jornada #

# %%
num_jornada = 8
division = 2
jornada_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league={division}&round={num_jornada}&order=twin&twolegged=1&year=2020"

# %%
response = requests.get(jornada_url)
result = json.loads(response.content)

# %%
result['match'][0]
# Out:
# {'id': '46778',
#  'year': '2020',
#  'group': '1',
#  'total_group': '1',
#  'round': '8',
#  'local': 'Las Palmas',
#  'visitor': 'Albacete',
#  'league_id': '50064',
#  'team1': '6283324',
#  'team2': '6283318',
#  'conference': '0',
#  'dteam1': '2563',
#  'dteam2': '140',
#  'numc': '0',
#  'no_hour': False,
#  'local_abbr': 'UDL',
#  'visitor_abbr': 'ALB',
#  'isVideo': 1,
#  'numVideos': '1',
#  'competition_name': 'Segunda División',
#  'competition_id': '2',
#  'split_league': '',
#  'type': 'Regular',
#  'type_id': '4',
#  'playoffs': False,
#  'group_code': '1',
#  'total_rounds': '42',
#  'coef': '70.641',
#  'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#  'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#  'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2563.jpg?size=60x&ext=png&lossy=1&v=8',
#  'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/140.jpg?size=60x&ext=png&lossy=1&v=8',
#  'extraTxt': 'Hace 1 año',
#  'schedule': '2019-09-27 21:00:00',
#  'date': '2019/09/27',
#  'hour': '21',
#  'minute': '00',
#  'local_goals': '3',
#  'visitor_goals': '2',
#  'result': '3-2',
#  'live_minute': '',
#  'status': 1,
#  'channels': [{'id': '325',
#    'name': 'M. LaLiga',
#    'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#  'winner': '6283324',
#  'penaltis1': 0,
#  'penaltis2': 0,
#  'prorroga': False}

# %% [markdown]
# # Petición Por Partido

# %%
match_url = 'https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league=1&round=7&order=twin&twolegged=1&year=2020'

# %%
response = requests.get(match_url)

# %%
result1 = json.loads(response.content)
result1
# Out:
# {'match': [{'id': '46367',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Villarreal',
#    'visitor': 'Real Betis',
#    'league_id': '49844',
#    'team1': '6279978',
#    'team2': '6279973',
#    'conference': '0',
#    'dteam1': '2716',
#    'dteam2': '486',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'VIL',
#    'visitor_abbr': 'BET',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2716.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/486.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-27 21:00:00',
#    'date': '2019/09/27',
#    'hour': '21',
#    'minute': '00',
#    'local_goals': '5',
#    'visitor_goals': '1',
#    'result': '5-1',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '20',
#      'name': 'Gol',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/20.png?size=50x'}],
#    'winner': '6279978',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46354',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Athletic',
#    'visitor': 'Valencia',
#    'league_id': '49844',
#    'team1': '6279963',
#    'team2': '6279977',
#    'conference': '0',
#    'dteam1': '347',
#    'dteam2': '2647',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ATH',
#    'visitor_abbr': 'VCF',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/347.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2647.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 13:00:00',
#    'date': '2019/09/28',
#    'hour': '13',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '1',
#    'result': '0-1',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279977',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46360',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Getafe',
#    'visitor': 'Barcelona',
#    'league_id': '49844',
#    'team1': '6279969',
#    'team2': '6279965',
#    'conference': '0',
#    'dteam1': '1217',
#    'dteam2': '429',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'GET',
#    'visitor_abbr': 'FCB',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1217.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/429.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 16:00:00',
#    'date': '2019/09/28',
#    'hour': '16',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '2',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279965',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46362',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Granada',
#    'visitor': 'Leganés',
#    'league_id': '49844',
#    'team1': '6281514',
#    'team2': '6279970',
#    'conference': '0',
#    'dteam1': '4235',
#    'dteam2': '1535',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'GRA',
#    'visitor_abbr': 'LEG',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/4235.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1535.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 18:30:00',
#    'date': '2019/09/28',
#    'hour': '18',
#    'minute': '30',
#    'local_goals': '1',
#    'visitor_goals': '0',
#    'result': '1-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6281514',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46304',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Atlético',
#    'visitor': 'Real Madrid',
#    'league_id': '49844',
#    'team1': '6279964',
#    'team2': '6279974',
#    'conference': '0',
#    'dteam1': '369',
#    'dteam2': '2107',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ATM',
#    'visitor_abbr': 'RMA',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/369.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2107.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 21:00:00',
#    'date': '2019/09/28',
#    'hour': '21',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '0',
#    'result': '0-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': 0,
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46359',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Espanyol',
#    'visitor': 'Real Valladolid',
#    'league_id': '49844',
#    'team1': '6279968',
#    'team2': '6279975',
#    'conference': '0',
#    'dteam1': '998',
#    'dteam2': '2654',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ESP',
#    'visitor_abbr': 'VAD',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/998.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2654.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 12:00:00',
#    'date': '2019/09/29',
#    'hour': '12',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '2',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279975',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46356',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Eibar',
#    'visitor': 'Celta',
#    'league_id': '49844',
#    'team1': '6279967',
#    'team2': '6279966',
#    'conference': '0',
#    'dteam1': '957',
#    'dteam2': '712',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'EIB',
#    'visitor_abbr': 'CEL',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/957.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/712.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 14:00:00',
#    'date': '2019/09/29',
#    'hour': '14',
#    'minute': '00',
#    'local_goals': '2',
#    'visitor_goals': '0',
#    'result': '2-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279967',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46353',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Alavés',
#    'visitor': 'Mallorca',
#    'league_id': '49844',
#    'team1': '6279962',
#    'team2': '6284662',
#    'conference': '0',
#    'dteam1': '137',
#    'dteam2': '1623',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ALA',
#    'visitor_abbr': 'MLL',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/137.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1623.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 16:00:00',
#    'date': '2019/09/29',
#    'hour': '16',
#    'minute': '00',
#    'local_goals': '2',
#    'visitor_goals': '0',
#    'result': '2-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279962',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46364',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Levante',
#    'visitor': 'Osasuna',
#    'league_id': '49844',
#    'team1': '6279971',
#    'team2': '6280105',
#    'conference': '0',
#    'dteam1': '1547',
#    'dteam2': '1887',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'LEV',
#    'visitor_abbr': 'OSA',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1547.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1887.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 18:30:00',
#    'date': '2019/09/29',
#    'hour': '18',
#    'minute': '30',
#    'local_goals': '1',
#    'visitor_goals': '1',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': 0,
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46366',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Sevilla',
#    'visitor': 'R. Sociedad',
#    'league_id': '49844',
#    'team1': '6279976',
#    'team2': '6279972',
#    'conference': '0',
#    'dteam1': '1102',
#    'dteam2': '2120',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'SEV',
#    'visitor_abbr': 'RSO',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '91.500',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1102.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2120.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 21:00:00',
#    'date': '2019/09/29',
#    'hour': '21',
#    'minute': '00',
#    'local_goals': '3',
#    'visitor_goals': '2',
#    'result': '3-2',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279976',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False}],
#  'twolegged': 0,
#  'linked_matches': 0}

# %% [markdown]
# ## Bucle Todas las jornadas

# %%
num_jornada = 0

match_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league=1&round={num_jornada}&order=twin&twolegged=1&year=2020"

def request2020():
    for i in match_url:
        num_jornada = num_jornada + 1
