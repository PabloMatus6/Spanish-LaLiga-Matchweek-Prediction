# %%
import pandas as pd
import numpy as np
import os
import json
import requests

# %%
endpoint_url = "https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchsday&date=2021-2-28&top=1"

# %%
response = requests.get(endpoint_url)

# %%
result = json.loads(response.content)

# %%
result
# Out:
# {'matches': [{'id': '89786',
#    'round': '25',
#    'local': 'Celta',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Real Valladolid',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380741',
#    'team2': '6380750',
#    'dteam1': '712',
#    'dteam2': '2654',
#    'local_abbr': 'CEL',
#    'visitor_abbr': 'VAD',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '76.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/712.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2654.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '14',
#    'minute': '00',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '89792',
#    'round': '25',
#    'local': 'Cádiz',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Real Betis',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380735',
#    'team2': '6380748',
#    'dteam1': '603',
#    'dteam2': '486',
#    'local_abbr': 'CAD',
#    'visitor_abbr': 'BET',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '76.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/603.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/486.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '16',
#    'minute': '15',
#    'result': '0-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6380748',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '89793',
#    'round': '25',
#    'local': 'Granada',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Elche',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380744',
#    'team2': '6391867',
#    'dteam1': '4235',
#    'dteam2': '975',
#    'local_abbr': 'GRA',
#    'visitor_abbr': 'ELC',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '76.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/4235.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/975.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '18',
#    'minute': '30',
#    'result': '2-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6380744',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '89802',
#    'round': '25',
#    'local': 'Villarreal',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Atlético',
#    'competition_name': 'Primera División',
#    'league_id': '57041',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '1',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6380753',
#    'team2': '6380739',
#    'dteam1': '2716',
#    'dteam2': '369',
#    'local_abbr': 'VIL',
#    'visitor_abbr': 'ATM',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '76.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2716.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/369.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '21',
#    'minute': '00',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6380739',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '72487',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Leicester',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Arsenal',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382967',
#    'team2': '6382960',
#    'dteam1': '1538',
#    'dteam2': '263',
#    'local_abbr': 'LEI',
#    'visitor_abbr': 'ARS',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '74.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1538.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/263.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '13',
#    'minute': '00',
#    'result': '1-3',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382960',
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72484',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Crystal Palace',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Fulham',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382965',
#    'team2': '6389128',
#    'dteam1': '860',
#    'dteam2': '1183',
#    'local_abbr': 'CRY',
#    'visitor_abbr': 'FUL',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '74.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/860.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1183.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '13',
#    'minute': '00',
#    'result': '0-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72491',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Tottenham Hotspur',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Burnley',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382974',
#    'team2': '6382963',
#    'dteam1': '2523',
#    'dteam2': '569',
#    'local_abbr': 'TOT',
#    'visitor_abbr': 'BUR',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '74.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2523.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/569.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '15',
#    'minute': '00',
#    'result': '4-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382974',
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72483',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Chelsea',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Man. Utd',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382964',
#    'team2': '6382970',
#    'dteam1': '752',
#    'dteam2': '1635',
#    'local_abbr': 'CHL',
#    'visitor_abbr': 'MUD',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '74.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/752.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1635.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '17',
#    'minute': '30',
#    'result': '0-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '72490',
#    'isVideo': 0,
#    'numVideos': 0,
#    'round': '26',
#    'local': 'Sheffield United',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Liverpool',
#    'competition_name': 'Premier League',
#    'league_id': '57338',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '10',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382972',
#    'team2': '6382968',
#    'dteam1': '9182',
#    'dteam2': '3845',
#    'local_abbr': 'SHE',
#    'visitor_abbr': 'LIV',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '74.000',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/9182.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/3845.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '20',
#    'minute': '15',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382968',
#    'channels': [{'id': '317',
#      'name': 'DAZN',
#      'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#   {'id': '90633',
#    'round': '27',
#    'local': 'Fuenlabrada',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Girona',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6387869',
#    'team2': '6391868',
#    'dteam1': '1179',
#    'dteam2': '1236',
#    'local_abbr': 'FUE',
#    'visitor_abbr': 'GIR',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '58.462',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1179.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1236.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '14',
#    'minute': '00',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '90634',
#    'round': '27',
#    'local': 'Real Sporting',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Espanyol',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382800',
#    'team2': '6382789',
#    'dteam1': '2125',
#    'dteam2': '998',
#    'local_abbr': 'SPO',
#    'visitor_abbr': 'ESP',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '58.462',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2125.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/998.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '16',
#    'minute': '00',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': 0,
#    'channels': [{'id': '303',
#      'name': '#Vamos',
#      'image': 'https://thumb.resfu.com/media/televisiones/303.png?size=50x'},
#     {'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '90639',
#    'round': '27',
#    'local': 'Tenerife',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Alcorcón',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382801',
#    'team2': '6382786',
#    'dteam1': '2477',
#    'dteam2': '64',
#    'local_abbr': 'CDT',
#    'visitor_abbr': 'ALC',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '58.462',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2477.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/64.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '18',
#    'minute': '15',
#    'result': '3-1',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382801',
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#   {'id': '90637',
#    'round': '27',
#    'local': 'Real Oviedo',
#    'group_code': '1',
#    'total_group': '1',
#    'visitor': 'Real Zaragoza',
#    'competition_name': 'Segunda División',
#    'league_id': '57314',
#    'extraName': '',
#    'conference': '0',
#    'category_id': '2',
#    'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#    'team1': '6382799',
#    'team2': '6390092',
#    'dteam1': '2115',
#    'dteam2': '2136',
#    'local_abbr': 'ROV',
#    'visitor_abbr': 'ZAR',
#    'numc': '0',
#    'year': '2021',
#    'playoffs': False,
#    'coef': '58.462',
#    'penaltis1': '',
#    'penaltis2': '',
#    'no_hour': False,
#    'extraTxt': 'Hace 3 meses',
#    'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2115.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2136.jpg?size=60x&ext=png&lossy=1&v=8',
#    'date': '2021/02/28',
#    'hour': '21',
#    'minute': '00',
#    'result': '1-0',
#    'live_minute': '',
#    'status': 1,
#    'winner': '6382799',
#    'channels': [{'id': '20',
#      'name': 'Gol',
#      'image': 'https://thumb.resfu.com/media/televisiones/20.png?size=50x'},
#     {'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]}],
#  'summary': {'today': '192', 'spain': '63', 'live': '0'}}

# %%
result['matches']
# Out:
# [{'id': '89786',
#   'round': '25',
#   'local': 'Celta',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Real Valladolid',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380741',
#   'team2': '6380750',
#   'dteam1': '712',
#   'dteam2': '2654',
#   'local_abbr': 'CEL',
#   'visitor_abbr': 'VAD',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '76.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/712.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2654.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '14',
#   'minute': '00',
#   'result': '1-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '89792',
#   'round': '25',
#   'local': 'Cádiz',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Real Betis',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380735',
#   'team2': '6380748',
#   'dteam1': '603',
#   'dteam2': '486',
#   'local_abbr': 'CAD',
#   'visitor_abbr': 'BET',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '76.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/603.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/486.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '16',
#   'minute': '15',
#   'result': '0-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6380748',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '89793',
#   'round': '25',
#   'local': 'Granada',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Elche',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380744',
#   'team2': '6391867',
#   'dteam1': '4235',
#   'dteam2': '975',
#   'local_abbr': 'GRA',
#   'visitor_abbr': 'ELC',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '76.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/4235.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/975.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '18',
#   'minute': '30',
#   'result': '2-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6380744',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '89802',
#   'round': '25',
#   'local': 'Villarreal',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Atlético',
#   'competition_name': 'Primera División',
#   'league_id': '57041',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '1',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/primera.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6380753',
#   'team2': '6380739',
#   'dteam1': '2716',
#   'dteam2': '369',
#   'local_abbr': 'VIL',
#   'visitor_abbr': 'ATM',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '76.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2716.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/369.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '21',
#   'minute': '00',
#   'result': '0-2',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6380739',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '72487',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Leicester',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Arsenal',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382967',
#   'team2': '6382960',
#   'dteam1': '1538',
#   'dteam2': '263',
#   'local_abbr': 'LEI',
#   'visitor_abbr': 'ARS',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '74.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1538.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/263.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '13',
#   'minute': '00',
#   'result': '1-3',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382960',
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72484',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Crystal Palace',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Fulham',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382965',
#   'team2': '6389128',
#   'dteam1': '860',
#   'dteam2': '1183',
#   'local_abbr': 'CRY',
#   'visitor_abbr': 'FUL',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '74.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/860.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1183.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '13',
#   'minute': '00',
#   'result': '0-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72491',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Tottenham Hotspur',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Burnley',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382974',
#   'team2': '6382963',
#   'dteam1': '2523',
#   'dteam2': '569',
#   'local_abbr': 'TOT',
#   'visitor_abbr': 'BUR',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '74.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2523.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/569.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '15',
#   'minute': '00',
#   'result': '4-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382974',
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72483',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Chelsea',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Man. Utd',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382964',
#   'team2': '6382970',
#   'dteam1': '752',
#   'dteam2': '1635',
#   'local_abbr': 'CHL',
#   'visitor_abbr': 'MUD',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '74.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/752.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1635.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '17',
#   'minute': '30',
#   'result': '0-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '72490',
#   'isVideo': 0,
#   'numVideos': 0,
#   'round': '26',
#   'local': 'Sheffield United',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Liverpool',
#   'competition_name': 'Premier League',
#   'league_id': '57338',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '10',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/premier.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382972',
#   'team2': '6382968',
#   'dteam1': '9182',
#   'dteam2': '3845',
#   'local_abbr': 'SHE',
#   'visitor_abbr': 'LIV',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '74.000',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/gb.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/9182.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/3845.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '20',
#   'minute': '15',
#   'result': '0-2',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382968',
#   'channels': [{'id': '317',
#     'name': 'DAZN',
#     'image': 'https://thumb.resfu.com/media/televisiones/317.png?size=50x'}]},
#  {'id': '90633',
#   'round': '27',
#   'local': 'Fuenlabrada',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Girona',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6387869',
#   'team2': '6391868',
#   'dteam1': '1179',
#   'dteam2': '1236',
#   'local_abbr': 'FUE',
#   'visitor_abbr': 'GIR',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '58.462',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1179.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1236.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '14',
#   'minute': '00',
#   'result': '1-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '90634',
#   'round': '27',
#   'local': 'Real Sporting',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Espanyol',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382800',
#   'team2': '6382789',
#   'dteam1': '2125',
#   'dteam2': '998',
#   'local_abbr': 'SPO',
#   'visitor_abbr': 'ESP',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '58.462',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2125.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/998.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '16',
#   'minute': '00',
#   'result': '1-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': 0,
#   'channels': [{'id': '303',
#     'name': '#Vamos',
#     'image': 'https://thumb.resfu.com/media/televisiones/303.png?size=50x'},
#    {'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '90639',
#   'round': '27',
#   'local': 'Tenerife',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Alcorcón',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382801',
#   'team2': '6382786',
#   'dteam1': '2477',
#   'dteam2': '64',
#   'local_abbr': 'CDT',
#   'visitor_abbr': 'ALC',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '58.462',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2477.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/64.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '18',
#   'minute': '15',
#   'result': '3-1',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382801',
#   'channels': [{'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]},
#  {'id': '90637',
#   'round': '27',
#   'local': 'Real Oviedo',
#   'group_code': '1',
#   'total_group': '1',
#   'visitor': 'Real Zaragoza',
#   'competition_name': 'Segunda División',
#   'league_id': '57314',
#   'extraName': '',
#   'conference': '0',
#   'category_id': '2',
#   'logo': 'https://thumb.resfu.com/media/img/league_logos/segunda.png?size=120x&ext=png&lossy=1&v=8',
#   'team1': '6382799',
#   'team2': '6390092',
#   'dteam1': '2115',
#   'dteam2': '2136',
#   'local_abbr': 'ROV',
#   'visitor_abbr': 'ZAR',
#   'numc': '0',
#   'year': '2021',
#   'playoffs': False,
#   'coef': '58.462',
#   'penaltis1': '',
#   'penaltis2': '',
#   'no_hour': False,
#   'extraTxt': 'Hace 3 meses',
#   'cflag': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#   'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2115.jpg?size=60x&ext=png&lossy=1&v=8',
#   'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2136.jpg?size=60x&ext=png&lossy=1&v=8',
#   'date': '2021/02/28',
#   'hour': '21',
#   'minute': '00',
#   'result': '1-0',
#   'live_minute': '',
#   'status': 1,
#   'winner': '6382799',
#   'channels': [{'id': '20',
#     'name': 'Gol',
#     'image': 'https://thumb.resfu.com/media/televisiones/20.png?size=50x'},
#    {'id': '325',
#     'name': 'M. LaLiga',
#     'image': 'https://thumb.resfu.com/media/televisiones/325.png?size=50x'}]}]

# %%
df = pd.DataFrame(result['matches'])

# %%
df['score_local'] = df['result'].apply(lambda x: x.split("-")[0])
df['score_visitor'] = df['result'].apply(lambda x: x.split("-")[1])

# %%
df.head()
# Out:
#       id round       local group_code total_group          visitor  \
# 0  89786    25       Celta          1           1  Real Valladolid
# 1  89792    25       Cádiz          1           1       Real Betis
# 2  89793    25     Granada          1           1            Elche
# 3  89802    25  Villarreal          1           1         Atlético
# 4  72487    26   Leicester          1           1          Arsenal
#
#    competition_name league_id extraName conference  ... minute result  \
# 0  Primera División     57041                    0  ...     00    1-1
# 1  Primera División     57041                    0  ...     15    0-1
# 2  Primera División     57041                    0  ...     30    2-1
# 3  Primera División     57041                    0  ...     00    0-2
# 4    Premier League     57338                    0  ...     00    1-3
#
#   live_minute status   winner  \
# 0                  1        0
# 1                  1  6380748
# 2                  1  6380744
# 3                  1  6380739
# 4                  1  6382960
#
#                                             channels isVideo numVideos  \
# 0  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 2  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 3  [{'id': '325', 'name': 'M. LaLiga', 'image': '...     NaN       NaN
# 4  [{'id': '317', 'name': 'DAZN', 'image': 'https...     0.0       0.0
#
#   score_local score_visitor
# 0           1             1
# 1           0             1
# 2           2             1
# 3           0             2
# 4           1             3
#
# [5 rows x 41 columns]

# %% [markdown]
# # Peticion Por Jornada #

# %%
num_jornada = 8
division = 2
jornada_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league={division}&round={num_jornada}&order=twin&twolegged=1&year=2020"

# %%
response = requests.get(jornada_url)
result = json.loads(response.content)

# %%
result['match'][0]
# Out:
# {'id': '46778',
#  'year': '2020',
#  'group': '1',
#  'total_group': '1',
#  'round': '8',
#  'local': 'Las Palmas',
#  'visitor': 'Albacete',
#  'league_id': '50064',
#  'stadium': 'Gran Canaria',
#  'team1': '6283324',
#  'team2': '6283318',
#  'conference': '0',
#  'dteam1': '2563',
#  'dteam2': '140',
#  'numc': '0',
#  'no_hour': False,
#  'local_abbr': 'UDL',
#  'visitor_abbr': 'ALB',
#  'isVideo': 1,
#  'numVideos': '1',
#  'competition_name': 'Segunda División',
#  'competition_id': '2',
#  'split_league': '',
#  'type': 'Regular',
#  'type_id': '4',
#  'playoffs': False,
#  'group_code': '1',
#  'total_rounds': '42',
#  'coef': '58.462',
#  'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#  'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#  'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2563.jpg?size=60x&ext=png&lossy=1&v=8',
#  'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/140.jpg?size=60x&ext=png&lossy=1&v=8',
#  'extraTxt': 'Hace 1 año',
#  'schedule': '2019-09-27 21:00:00',
#  'date': '2019/09/27',
#  'hour': '21',
#  'minute': '00',
#  'local_goals': '3',
#  'visitor_goals': '2',
#  'result': '3-2',
#  'live_minute': '',
#  'status': 1,
#  'channels': [{'id': '325',
#    'name': 'M. LaLiga',
#    'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#  'winner': '6283324',
#  'penaltis1': 0,
#  'penaltis2': 0,
#  'prorroga': False}

# %% [markdown]
# # Petición Por Partido

# %%
match_url = 'https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league=1&round=7&order=twin&twolegged=1&year=2020'

# %%
response = requests.get(match_url)

# %%
result1 = json.loads(response.content)
result1
# Out:
# {'match': [{'id': '46367',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Villarreal',
#    'visitor': 'Real Betis',
#    'league_id': '49844',
#    'stadium': 'Estadio de la Cerámica',
#    'team1': '6279978',
#    'team2': '6279973',
#    'conference': '0',
#    'dteam1': '2716',
#    'dteam2': '486',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'VIL',
#    'visitor_abbr': 'BET',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2716.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/486.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-27 21:00:00',
#    'date': '2019/09/27',
#    'hour': '21',
#    'minute': '00',
#    'local_goals': '5',
#    'visitor_goals': '1',
#    'result': '5-1',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '20',
#      'name': 'Gol',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/20.png?size=50x'}],
#    'winner': '6279978',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46354',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Athletic',
#    'visitor': 'Valencia',
#    'league_id': '49844',
#    'stadium': 'San Mamés',
#    'team1': '6279963',
#    'team2': '6279977',
#    'conference': '0',
#    'dteam1': '347',
#    'dteam2': '2647',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ATH',
#    'visitor_abbr': 'VCF',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/347.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2647.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 13:00:00',
#    'date': '2019/09/28',
#    'hour': '13',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '1',
#    'result': '0-1',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279977',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46360',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Getafe',
#    'visitor': 'Barcelona',
#    'league_id': '49844',
#    'stadium': 'Coliseum Alfonso Pérez',
#    'team1': '6279969',
#    'team2': '6279965',
#    'conference': '0',
#    'dteam1': '1217',
#    'dteam2': '429',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'GET',
#    'visitor_abbr': 'FCB',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1217.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/429.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 16:00:00',
#    'date': '2019/09/28',
#    'hour': '16',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '2',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279965',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46362',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Granada',
#    'visitor': 'Leganés',
#    'league_id': '49844',
#    'stadium': 'Nuevo Los Cármenes',
#    'team1': '6281514',
#    'team2': '6279970',
#    'conference': '0',
#    'dteam1': '4235',
#    'dteam2': '1535',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'GRA',
#    'visitor_abbr': 'LEG',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/4235.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1535.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 18:30:00',
#    'date': '2019/09/28',
#    'hour': '18',
#    'minute': '30',
#    'local_goals': '1',
#    'visitor_goals': '0',
#    'result': '1-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6281514',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46304',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Atlético',
#    'visitor': 'Real Madrid',
#    'league_id': '49844',
#    'stadium': 'Wanda Metropolitano',
#    'team1': '6279964',
#    'team2': '6279974',
#    'conference': '0',
#    'dteam1': '369',
#    'dteam2': '2107',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ATM',
#    'visitor_abbr': 'RMA',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/369.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2107.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-28 21:00:00',
#    'date': '2019/09/28',
#    'hour': '21',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '0',
#    'result': '0-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': 0,
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46359',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Espanyol',
#    'visitor': 'Real Valladolid',
#    'league_id': '49844',
#    'stadium': 'RCDE Stadium',
#    'team1': '6279968',
#    'team2': '6279975',
#    'conference': '0',
#    'dteam1': '998',
#    'dteam2': '2654',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ESP',
#    'visitor_abbr': 'VAD',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/998.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2654.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 12:00:00',
#    'date': '2019/09/29',
#    'hour': '12',
#    'minute': '00',
#    'local_goals': '0',
#    'visitor_goals': '2',
#    'result': '0-2',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279975',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46356',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Eibar',
#    'visitor': 'Celta',
#    'league_id': '49844',
#    'stadium': 'Municipal de Ipurua',
#    'team1': '6279967',
#    'team2': '6279966',
#    'conference': '0',
#    'dteam1': '957',
#    'dteam2': '712',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'EIB',
#    'visitor_abbr': 'CEL',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/957.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/712.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 14:00:00',
#    'date': '2019/09/29',
#    'hour': '14',
#    'minute': '00',
#    'local_goals': '2',
#    'visitor_goals': '0',
#    'result': '2-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279967',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46353',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Alavés',
#    'visitor': 'Mallorca',
#    'league_id': '49844',
#    'stadium': 'Mendizorroza',
#    'team1': '6279962',
#    'team2': '6284662',
#    'conference': '0',
#    'dteam1': '137',
#    'dteam2': '1623',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'ALA',
#    'visitor_abbr': 'MLL',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/137.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1623.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 16:00:00',
#    'date': '2019/09/29',
#    'hour': '16',
#    'minute': '00',
#    'local_goals': '2',
#    'visitor_goals': '0',
#    'result': '2-0',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279962',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46364',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Levante',
#    'visitor': 'Osasuna',
#    'league_id': '49844',
#    'stadium': 'Ciutat de València',
#    'team1': '6279971',
#    'team2': '6280105',
#    'conference': '0',
#    'dteam1': '1547',
#    'dteam2': '1887',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'LEV',
#    'visitor_abbr': 'OSA',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1547.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1887.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 18:30:00',
#    'date': '2019/09/29',
#    'hour': '18',
#    'minute': '30',
#    'local_goals': '1',
#    'visitor_goals': '1',
#    'result': '1-1',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': 0,
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False},
#   {'id': '46366',
#    'year': '2020',
#    'group': '1',
#    'total_group': '1',
#    'round': '7',
#    'local': 'Sevilla',
#    'visitor': 'R. Sociedad',
#    'league_id': '49844',
#    'stadium': 'Ramón Sánchez Pizjuán',
#    'team1': '6279976',
#    'team2': '6279972',
#    'conference': '0',
#    'dteam1': '1102',
#    'dteam2': '2120',
#    'numc': '0',
#    'no_hour': False,
#    'local_abbr': 'SEV',
#    'visitor_abbr': 'RSO',
#    'isVideo': 1,
#    'numVideos': '1',
#    'competition_name': 'Primera División',
#    'competition_id': '1',
#    'split_league': '',
#    'type': 'Regular',
#    'type_id': '4',
#    'playoffs': False,
#    'group_code': '1',
#    'total_rounds': '38',
#    'coef': '76.000',
#    'cflag_local': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'cflag_visitor': 'https://thumb.resfu.com/media/img/flags/st3/large/es.png?size=100x65c&ext=png&lossy=1&v=8',
#    'local_shield': 'https://thumb.resfu.com/img_data/escudos/medium/1102.jpg?size=60x&ext=png&lossy=1&v=8',
#    'visitor_shield': 'https://thumb.resfu.com/img_data/escudos/medium/2120.jpg?size=60x&ext=png&lossy=1&v=8',
#    'extraTxt': 'Hace 1 año',
#    'schedule': '2019-09-29 21:00:00',
#    'date': '2019/09/29',
#    'hour': '21',
#    'minute': '00',
#    'local_goals': '3',
#    'visitor_goals': '2',
#    'result': '3-2',
#    'live_minute': '',
#    'status': 1,
#    'channels': [{'id': '325',
#      'name': 'M. LaLiga',
#      'image': 'https://apiclient.besoccerapps.com/media/televisiones/325.png?size=50x'}],
#    'winner': '6279976',
#    'penaltis1': 0,
#    'penaltis2': 0,
#    'prorroga': False}],
#  'twolegged': 0,
#  'linked_matches': 0}

# %% [markdown]
# ## Bucle Todas las jornadas

# %%
#Todas las jornadas primera division temporada 2020

for num_jorn in range(1, 39):
    round_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league=1&round={num_jorn}&order=twin&twolegged=1&year=2020"
    response1 = requests.get(round_url)
    result1 = json.loads(response1.content)
    if num_jorn == 1:
        df1 = pd.DataFrame(result1['match'])
    else:
        df1 = df1.append(result1['match'])

# %%
df1
# Out:
#        id  year group total_group round     local      visitor league_id  \
# 0   46292  2020     1           1     1  Athletic    Barcelona     49844
# 1   46281  2020     1           1     1     Celta  Real Madrid     49844
# 2   46288  2020     1           1     1  Valencia  R. Sociedad     49844
# 3   46282  2020     1           1     1  Mallorca        Eibar     49844
# 4   46290  2020     1           1     1   Leganés      Osasuna     49844
# ..    ...   ...   ...         ...   ...       ...          ...       ...
# 5   46303  2020     1           1    38   Granada     Athletic     49844
# 6   46307  2020     1           1    38  Atlético  R. Sociedad     49844
# 7   46298  2020     1           1    38   Sevilla     Valencia     49844
# 8   46300  2020     1           1    38   Levante       Getafe     49844
# 9   46305  2020     1           1    38   Osasuna     Mallorca     49844
#
#                   stadium    team1  ... live_minute status  \
# 0               San Mamés  6279963  ...                  1
# 1         Abanca Balaídos  6279966  ...                  1
# 2                Mestalla  6279977  ...                  1
# 3    Visit Mallora Estadi  6284662  ...                  1
# 4   Municipal de Butarque  6279970  ...                  1
# ..                    ...      ...  ...         ...    ...
# 5      Nuevo Los Cármenes  6281514  ...                  1
# 6     Wanda Metropolitano  6279964  ...                  1
# 7   Ramón Sánchez Pizjuán  6279976  ...                  1
# 8      Ciutat de València  6279971  ...                  1
# 9                El Sadar  6280105  ...                  1
#
#                                              channels   winner penaltis1  \
# 0   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279963         0
# 1   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279974         0
# 2   [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
# 3   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6284662         0
# 4   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6280105         0
# ..                                                ...      ...       ...
# 5   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6281514         0
# 6   [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
# 7   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279976         0
# 8   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279971         0
# 9   [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
#
#     penaltis2 prorroga isVideo numVideos stadium2
# 0           0    False     NaN       NaN      NaN
# 1           0    False     NaN       NaN      NaN
# 2           0    False     NaN       NaN      NaN
# 3           0    False     NaN       NaN      NaN
# 4           0    False     NaN       NaN      NaN
# ..        ...      ...     ...       ...      ...
# 5           0    False     1.0         1      NaN
# 6           0    False     1.0         1      NaN
# 7           0    False     1.0         1      NaN
# 8           0    False     1.0         1    False
# 9           0    False     1.0         1      NaN
#
# [380 rows x 49 columns]

# %%
df1.columns
# Out:
# Index(['id', 'year', 'group', 'total_group', 'round', 'local', 'visitor',
#        'league_id', 'stadium', 'team1', 'team2', 'conference', 'dteam1',
#        'dteam2', 'numc', 'no_hour', 'local_abbr', 'visitor_abbr',
#        'competition_name', 'competition_id', 'split_league', 'type', 'type_id',
#        'playoffs', 'group_code', 'total_rounds', 'coef', 'cflag_local',
#        'cflag_visitor', 'local_shield', 'visitor_shield', 'extraTxt',
#        'schedule', 'date', 'hour', 'minute', 'local_goals', 'visitor_goals',
#        'result', 'live_minute', 'status', 'channels', 'winner', 'penaltis1',
#        'penaltis2', 'prorroga', 'isVideo', 'numVideos', 'stadium2'],
#       dtype='object')

# %%
df1.tail()
# Out:
#       id  year group total_group round     local      visitor league_id  \
# 5  46303  2020     1           1    38   Granada     Athletic     49844
# 6  46307  2020     1           1    38  Atlético  R. Sociedad     49844
# 7  46298  2020     1           1    38   Sevilla     Valencia     49844
# 8  46300  2020     1           1    38   Levante       Getafe     49844
# 9  46305  2020     1           1    38   Osasuna     Mallorca     49844
#
#                  stadium    team1  ... live_minute status  \
# 5     Nuevo Los Cármenes  6281514  ...                  1
# 6    Wanda Metropolitano  6279964  ...                  1
# 7  Ramón Sánchez Pizjuán  6279976  ...                  1
# 8     Ciutat de València  6279971  ...                  1
# 9               El Sadar  6280105  ...                  1
#
#                                             channels   winner penaltis1  \
# 5  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6281514         0
# 6  [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
# 7  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279976         0
# 8  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279971         0
# 9  [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
#
#    penaltis2 prorroga isVideo numVideos stadium2
# 5          0    False     1.0         1      NaN
# 6          0    False     1.0         1      NaN
# 7          0    False     1.0         1      NaN
# 8          0    False     1.0         1    False
# 9          0    False     1.0         1      NaN
#
# [5 rows x 49 columns]

# %%
#Bucle para segunda división
for num_jorn in range(1, 43):
    round_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league=3&round={num_jorn}&order=twin&twolegged=1&year=2020"
    response2 = requests.get(round_url)
    result2 = json.loads(response1.content)
    if num_jorn == 1:
        df2 = pd.DataFrame(result1['match'])
    else:
        df2 = df1.append(result1['match'])

# %%
df2
# Out:
#        id  year group total_group round     local      visitor league_id  \
# 0   46292  2020     1           1     1  Athletic    Barcelona     49844
# 1   46281  2020     1           1     1     Celta  Real Madrid     49844
# 2   46288  2020     1           1     1  Valencia  R. Sociedad     49844
# 3   46282  2020     1           1     1  Mallorca        Eibar     49844
# 4   46290  2020     1           1     1   Leganés      Osasuna     49844
# ..    ...   ...   ...         ...   ...       ...          ...       ...
# 5   46303  2020     1           1    38   Granada     Athletic     49844
# 6   46307  2020     1           1    38  Atlético  R. Sociedad     49844
# 7   46298  2020     1           1    38   Sevilla     Valencia     49844
# 8   46300  2020     1           1    38   Levante       Getafe     49844
# 9   46305  2020     1           1    38   Osasuna     Mallorca     49844
#
#                   stadium    team1  ... live_minute status  \
# 0               San Mamés  6279963  ...                  1
# 1         Abanca Balaídos  6279966  ...                  1
# 2                Mestalla  6279977  ...                  1
# 3    Visit Mallora Estadi  6284662  ...                  1
# 4   Municipal de Butarque  6279970  ...                  1
# ..                    ...      ...  ...         ...    ...
# 5      Nuevo Los Cármenes  6281514  ...                  1
# 6     Wanda Metropolitano  6279964  ...                  1
# 7   Ramón Sánchez Pizjuán  6279976  ...                  1
# 8      Ciutat de València  6279971  ...                  1
# 9                El Sadar  6280105  ...                  1
#
#                                              channels   winner penaltis1  \
# 0   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279963         0
# 1   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279974         0
# 2   [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
# 3   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6284662         0
# 4   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6280105         0
# ..                                                ...      ...       ...
# 5   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6281514         0
# 6   [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
# 7   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279976         0
# 8   [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6279971         0
# 9   [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0         0
#
#     penaltis2 prorroga isVideo numVideos stadium2
# 0           0    False     NaN       NaN      NaN
# 1           0    False     NaN       NaN      NaN
# 2           0    False     NaN       NaN      NaN
# 3           0    False     NaN       NaN      NaN
# 4           0    False     NaN       NaN      NaN
# ..        ...      ...     ...       ...      ...
# 5           0    False     1.0         1      NaN
# 6           0    False     1.0         1      NaN
# 7           0    False     1.0         1      NaN
# 8           0    False     1.0         1    False
# 9           0    False     1.0         1      NaN
#
# [390 rows x 49 columns]

# %% [markdown]
# # All seasons Loop

# %%
#Year2021
for num_jorn in range(1, 39):
    round_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=matchs&league=1&round={num_jorn}&order=twin&twolegged=1&year=2021"
    response1 = requests.get(round_url)
    result1 = json.loads(response1.content)
    if num_jorn == 1:
        df10 = pd.DataFrame(result1['match'])
    else:
        df10 = df10.append(result1['match'])

# %%
df10
# Out:
#        id  year group total_group round            local      visitor  \
# 0   89529  2021     1           1     1            Eibar        Celta
# 1   89531  2021     1           1     1          Granada     Athletic
# 2   89530  2021     1           1     1            Cádiz      Osasuna
# 3   89526  2021     1           1     1           Alavés   Real Betis
# 4   89534  2021     1           1     1  Real Valladolid  R. Sociedad
# ..    ...   ...   ...         ...   ...              ...          ...
# 5   89546  2021     1           1    38            Celta   Real Betis
# 6   89557  2021     1           1    38      Real Madrid   Villarreal
# 7   89562  2021     1           1    38  Real Valladolid     Atlético
# 8   89549  2021     1           1    38          Granada       Getafe
# 9   89560  2021     1           1    38          Sevilla       Alavés
#
#    league_id                  stadium    team1  ... visitor_goals result  \
# 0      57041      Municipal de Ipurua  6380742  ...             0    0-0
# 1      57041       Nuevo Los Cármenes  6380744  ...             0    2-0
# 2      57041  Nuevo Ramón de Carranza  6380735  ...             2    0-2
# 3      57041             Mendizorroza  6380737  ...             1    0-1
# 4      57041  Municipal José Zorrilla  6380750  ...             1    1-1
# ..       ...                      ...      ...  ...           ...    ...
# 5      57041          Abanca Balaídos  6380741  ...             3    2-3
# 6      57041        Santiago Bernabéu  6380749  ...             1    2-1
# 7      57041  Municipal José Zorrilla  6380750  ...             2    1-2
# 8      57041       Nuevo Los Cármenes  6380744  ...             0    0-0
# 9      57041    Ramón Sánchez Pizjuán  6380751  ...             0    1-0
#
#    live_minute status                                           channels  \
# 0                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# 1                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# 2                   1  [{'id': '8286', 'name': 'Movistar LaLiga', 'im...
# 3                   1  [{'id': '20', 'name': 'Gol', 'image': 'https:/...
# 4                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# ..         ...    ...                                                ...
# 5                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# 6                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# 7                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# 8                   1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...
# 9                   1  [{'id': '20', 'name': 'Gol', 'image': 'https:/...
#
#      winner penaltis1 penaltis2  prorroga stadium2
# 0         0         0         0     False      NaN
# 1   6380744         0         0     False      NaN
# 2   6380746         0         0     False      NaN
# 3   6380748         0         0     False      NaN
# 4         0         0         0     False      NaN
# ..      ...       ...       ...       ...      ...
# 5   6380748         0         0     False      NaN
# 6   6380749         0         0     False    False
# 7   6380739         0         0     False      NaN
# 8         0         0         0     False      NaN
# 9   6380751         0         0     False      NaN
#
# [380 rows x 49 columns]

# %%
df10.tail()
# Out:
#       id  year group total_group round            local     visitor league_id  \
# 5  89546  2021     1           1    38            Celta  Real Betis     57041
# 6  89557  2021     1           1    38      Real Madrid  Villarreal     57041
# 7  89562  2021     1           1    38  Real Valladolid    Atlético     57041
# 8  89549  2021     1           1    38          Granada      Getafe     57041
# 9  89560  2021     1           1    38          Sevilla      Alavés     57041
#
#                    stadium    team1  ... visitor_goals result live_minute  \
# 5          Abanca Balaídos  6380741  ...             3    2-3
# 6        Santiago Bernabéu  6380749  ...             1    2-1
# 7  Municipal José Zorrilla  6380750  ...             2    1-2
# 8       Nuevo Los Cármenes  6380744  ...             0    0-0
# 9    Ramón Sánchez Pizjuán  6380751  ...             0    1-0
#
#   status                                           channels   winner  \
# 5      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380748
# 6      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 7      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380739
# 8      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0
# 9      1  [{'id': '20', 'name': 'Gol', 'image': 'https:/...  6380751
#
#   penaltis1 penaltis2  prorroga stadium2
# 5         0         0     False      NaN
# 6         0         0     False    False
# 7         0         0     False      NaN
# 8         0         0     False      NaN
# 9         0         0     False      NaN
#
# [5 rows x 49 columns]

# %%
df10.columns
# Out:
# Index(['id', 'year', 'group', 'total_group', 'round', 'local', 'visitor',
#        'league_id', 'stadium', 'team1', 'team2', 'conference', 'dteam1',
#        'dteam2', 'numc', 'no_hour', 'local_abbr', 'visitor_abbr', 'isVideo',
#        'numVideos', 'competition_name', 'competition_id', 'split_league',
#        'type', 'type_id', 'playoffs', 'group_code', 'total_rounds', 'coef',
#        'cflag_local', 'cflag_visitor', 'local_shield', 'visitor_shield',
#        'extraTxt', 'schedule', 'date', 'hour', 'minute', 'local_goals',
#        'visitor_goals', 'result', 'live_minute', 'status', 'channels',
#        'winner', 'penaltis1', 'penaltis2', 'prorroga', 'stadium2'],
#       dtype='object')

# %% [markdown]
# # Standings request

# %%
for league_division in range(1, 3):
    for league_season in range(2018, 2022):
        for league_round in range(1, 39):
            standings_url = f"https://apiclient.besoccerapps.com/scripts/api/api.php?key=023afbc77c5610fefc3fc8976e451752&tz=Europe/Madrid&format=json&req=tables&league={league_division}&round={league_round}&year={league_season}"
            response_standings = requests.get(standings_url)
            result_standings = json.loads(response_standings.content)
            if league_round == 1 and league_division == 1 and league_season == 2018:
                df3 = pd.DataFrame(result_standings['table'])
            else:
                df3 = df3.append(result_standings['table'])

# %%
df3
# Out:
#       id group group_name conference          team points  wins  draws  \
# 0   2107     1                     0   Real Madrid      3     1      0
# 1    429     1                     0     Barcelona      3     1      0
# 2   2120     1                     0   R. Sociedad      3     1      0
# 3    957     1                     0         Eibar      3     1      0
# 4   1535     1                     0       Leganés      3     1      0
# ..   ...   ...        ...        ...           ...    ...   ...    ...
# 17   673     1                     0  CD Castellón     41    11      8
# 18  1578     1                     0   UD Logroñés     41    10     11
# 19  2198     1                     0      Sabadell     40     9     13
# 20  1598     1                     0          Lugo     37     8     13
# 21   140     1                     0      Albacete     36     9      9
#
#     losses                                             shield  ... coef  \
# 0        0  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 1        0  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 2        0  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 3        0  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 4        0  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# ..     ...                                                ...  ...  ...
# 17      19  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 18      17  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 19      16  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 20      17  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 21      20  https://thumb.resfu.com/img_data/escudos/mediu...  ...
#
#    coefficients mark class_mark  round pos countrycode abbr   form direction
# 0          None    1        cha      1   1          ES  RMA      w
# 1          None    1        cha      1   2          ES  FCB      w
# 2          None    1        cha      1   3          ES  RSO      w
# 3          None    1        cha      1   4          ES  EIB      w
# 4          None    2       uefa      1   5          ES  LEG      w
# ..          ...  ...        ...    ...  ..         ...  ...    ...       ...
# 17         None                     38  18          ES  CAS  lwddl
# 18         None    3       desc     38  19          ES  UDL  wdldl         d
# 19         None    3       desc     38  20          ES  SAB  ddwwl         d
# 20         None    3       desc     38  21          ES  LUG  llldl
# 21         None    3       desc     38  22          ES  ALB  lwdlw
#
# [6384 rows x 27 columns]

# %%
df3.tail()
# Out:
#       id group group_name conference          team points  wins  draws  \
# 17   673     1                     0  CD Castellón     41    11      8
# 18  1578     1                     0   UD Logroñés     41    10     11
# 19  2198     1                     0      Sabadell     40     9     13
# 20  1598     1                     0          Lugo     37     8     13
# 21   140     1                     0      Albacete     36     9      9
#
#     losses                                             shield  ... coef  \
# 17      19  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 18      17  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 19      16  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 20      17  https://thumb.resfu.com/img_data/escudos/mediu...  ...
# 21      20  https://thumb.resfu.com/img_data/escudos/mediu...  ...
#
#    coefficients mark class_mark  round pos countrycode abbr   form direction
# 17         None                     38  18          ES  CAS  lwddl
# 18         None    3       desc     38  19          ES  UDL  wdldl         d
# 19         None    3       desc     38  20          ES  SAB  ddwwl         d
# 20         None    3       desc     38  21          ES  LUG  llldl
# 21         None    3       desc     38  22          ES  ALB  lwdlw
#
# [5 rows x 27 columns]

# %%
df3.columns
# Out:
# Index(['id', 'group', 'group_name', 'conference', 'team', 'points', 'wins',
#        'draws', 'losses', 'shield', 'cflag', 'basealias', 'gf', 'ga', 'avg',
#        'matchs_coef', 'points_coef', 'coef', 'coefficients', 'mark',
#        'class_mark', 'round', 'pos', 'countrycode', 'abbr', 'form',
#        'direction'],
#       dtype='object')

# %%
df3 = df3.drop(['group', 'group_name', 'conference', 'shield', 'cflag', 'basealias',
       'matchs_coef', 'points_coef', 'coef', 'coefficients', 'mark',
       'class_mark', 'round', 'pos', 'countrycode', 'abbr', 'form',
       'direction'] , axis = 1 )

# %%
df3
# Out:
#       id          team points  wins  draws  losses  gf  ga  avg
# 0   2107   Real Madrid      3     1      0       0   3   0    3
# 1    429     Barcelona      3     1      0       0   2   0    2
# 2   2120   R. Sociedad      3     1      0       0   3   2    1
# 3    957         Eibar      3     1      0       0   1   0    1
# 4   1535       Leganés      3     1      0       0   1   0    1
# ..   ...           ...    ...   ...    ...     ...  ..  ..  ...
# 17   673  CD Castellón     41    11      8      19  35  44   -9
# 18  1578   UD Logroñés     41    10     11      17  26  47  -21
# 19  2198      Sabadell     40     9     13      16  36  44   -8
# 20  1598          Lugo     37     8     13      17  32  50  -18
# 21   140      Albacete     36     9      9      20  25  46  -21
#
# [6384 rows x 9 columns]

# %%
df3.tail()
# Out:
#       id          team points  wins  draws  losses  gf  ga  avg
# 17   673  CD Castellón     41    11      8      19  35  44   -9
# 18  1578   UD Logroñés     41    10     11      17  26  47  -21
# 19  2198      Sabadell     40     9     13      16  36  44   -8
# 20  1598          Lugo     37     8     13      17  32  50  -18
# 21   140      Albacete     36     9      9      20  25  46  -21

# %% [markdown]
# Para hacer el merge, primero vemos que key podemos utilizar, intentamos la columna id

# %%
realmadrid_id = df3['id'] == '2107'
realmadrid_id.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: id, dtype: bool

# %%
realmadrid_standings = df3[realmadrid_id]
realmadrid_standings.head()
# Out:
#      id         team points  wins  draws  losses gf ga  avg
# 0  2107  Real Madrid      3     1      0       0  3  0    3
# 5  2107  Real Madrid      4     1      1       0  5  2    3
# 6  2107  Real Madrid      5     1      2       0  6  3    3
# 3  2107  Real Madrid      8     2      2       0  9  4    5
# 7  2107  Real Madrid      8     2      2       1  9  5    4

# %%
realmadrid_standings.tail()
# Out:
#      id         team points  wins  draws  losses  gf  ga  avg
# 1  2107  Real Madrid     74    22      8       4  58  24   34
# 1  2107  Real Madrid     75    22      9       4  60  26   34
# 1  2107  Real Madrid     78    23      9       4  64  27   37
# 1  2107  Real Madrid     81    24      9       4  65  27   38
# 1  2107  Real Madrid     84    25      9       4  67  28   39

# %% [markdown]
# We look now if the id for real madrid (example) is the same in the matches request

# %%
realmadrid_id_matches = df10['dteam1'] == '2107'
realmadrid_id.head()
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: id, dtype: bool

# %%
realmadrid_matches = df10[realmadrid_id_matches]
realmadrid_matches
# Out:
#       id  year group total_group round        local          visitor  \
# 8  89532  2021     1           1     1  Real Madrid           Getafe
# 5  89585  2021     1           1     4  Real Madrid  Real Valladolid
# 2  89618  2021     1           1     6  Real Madrid            Cádiz
# 1  89621  2021     1           1     8  Real Madrid           Huesca
# 4  89637  2021     1           1    11  Real Madrid           Alavés
# 4  89538  2021     1           1    13  Real Madrid         Atlético
# 7  89692  2021     1           1    15  Real Madrid          Granada
# 3  89712  2021     1           1    17  Real Madrid            Celta
# 0  89733  2021     1           1    19  Real Madrid         Athletic
# 2  89755  2021     1           1    21  Real Madrid          Levante
# 6  89778  2021     1           1    23  Real Madrid         Valencia
# 9  89798  2021     1           1    25  Real Madrid      R. Sociedad
# 2  89809  2021     1           1    27  Real Madrid            Elche
# 2  89837  2021     1           1    29  Real Madrid            Eibar
# 4  89537  2021     1           1    30  Real Madrid        Barcelona
# 3  89855  2021     1           1    32  Real Madrid       Real Betis
# 4  89875  2021     1           1    34  Real Madrid          Osasuna
# 8  89890  2021     1           1    35  Real Madrid          Sevilla
# 6  89557  2021     1           1    38  Real Madrid       Villarreal
#
#   league_id            stadium    team1  ... visitor_goals result live_minute  \
# 8     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 5     57041  Santiago Bernabéu  6380749  ...             0    1-0
# 2     57041  Santiago Bernabéu  6380749  ...             1    0-1
# 1     57041  Santiago Bernabéu  6380749  ...             1    4-1
# 4     57041  Santiago Bernabéu  6380749  ...             2    1-2
# 4     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 7     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 3     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 0     57041  Santiago Bernabéu  6380749  ...             1    3-1
# 2     57041  Santiago Bernabéu  6380749  ...             2    1-2
# 6     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 9     57041  Santiago Bernabéu  6380749  ...             1    1-1
# 2     57041  Santiago Bernabéu  6380749  ...             1    2-1
# 2     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 4     57041  Santiago Bernabéu  6380749  ...             1    2-1
# 3     57041  Santiago Bernabéu  6380749  ...             0    0-0
# 4     57041  Santiago Bernabéu  6380749  ...             0    2-0
# 8     57041  Santiago Bernabéu  6380749  ...             2    2-2
# 6     57041  Santiago Bernabéu  6380749  ...             1    2-1
#
#   status                                           channels   winner  \
# 8      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 5      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 2      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380735
# 1      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 4      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380737
# 4      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 7      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 3      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 0      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 2      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380745
# 6      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 9      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0
# 2      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 2      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 4      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 3      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0
# 4      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
# 8      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...        0
# 6      1  [{'id': '325', 'name': 'M. LaLiga', 'image': '...  6380749
#
#   penaltis1 penaltis2  prorroga stadium2
# 8         0         0     False    False
# 5         0         0     False    False
# 2         0         0     False    False
# 1         0         0     False    False
# 4         0         0     False    False
# 4         0         0     False    False
# 7         0         0     False    False
# 3         0         0     False    False
# 0         0         0     False    False
# 2         0         0     False    False
# 6         0         0     False    False
# 9         0         0     False    False
# 2         0         0     False    False
# 2         0         0     False    False
# 4         0         0     False    False
# 3         0         0     False    False
# 4         0         0     False    False
# 8         0         0     False    False
# 6         0         0     False    False
#
# [19 rows x 49 columns]

# %%
realmadrid_matches['dteam1']
# Out:
# 8    2107
# 5    2107
# 2    2107
# 1    2107
# 4    2107
# 4    2107
# 7    2107
# 3    2107
# 0    2107
# 2    2107
# 6    2107
# 9    2107
# 2    2107
# 2    2107
# 4    2107
# 3    2107
# 4    2107
# 8    2107
# 6    2107
# Name: dteam1, dtype: object

# %% [markdown]
# Ya sabemos que la columna id en la request de standings es la key en comun con la columna dteam1 o dteam 2 en la request de matches
