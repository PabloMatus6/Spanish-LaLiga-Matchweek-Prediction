# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
plotting_data = pd.read_csv('plotting_data')

# %%
plotting_data.tail(5)
# Out:
#       Unnamed: 0  year  round  division  local_goals  visitor_goals  \
# 4921        4921  2021     38         2            2              1
# 4922        4922  2021     38         2            1              4
# 4923        4923  2021     38         2            1              0
# 4924        4924  2021     38         2            1              1
# 4925        4925  2021     38         2            1              0
#
#       points_local  wins_local  draws_local  losses_local  ...  pos_local  \
# 4921            44         9.0         17.0          11.0  ...         14
# 4922            41        10.0         11.0          16.0  ...         17
# 4923            39         9.0         12.0          16.0  ...         20
# 4924            57        16.0          9.0          12.0  ...          7
# 4925            58        15.0         13.0           9.0  ...          5
#
#       points_visitor  wins_visitor  draws_visitor  losses_visitor  gf_visitor  \
# ...
