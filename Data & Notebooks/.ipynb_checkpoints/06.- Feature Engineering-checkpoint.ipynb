# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# We go back to the data we saved in notebook 05, as it contains the same information as in plotting data and also some str type columns that we could not plot but from which we could extract information during the feature engineering.

# %%
df = pd.read_csv('Cleaned Data', index_col = [0])
df.tail(5)
# Out:
#       match_id  year  round           local       visitor  league_id  \
# 4657     91110  2021     38     Real Oviedo      Sabadell      57314
# 4658     91104  2021     38    FC Cartagena  CD Castellón      57314
# 4659     91112  2021     38     UD Logroñés        Girona      57314
# 4660     91109  2021     38  Rayo Vallecano       Leganés      57314
# 4661     91105  2021     38   Real Sporting          Lugo      57314
#
#       team1_id_season  team2_id_season  team1_id  team2_id  ...  \
# 4657          6382799          6382802      2115      2198  ...
# 4658          6382787          6382788       643       673  ...
# 4659          6382792          6391868      1578      1236  ...
# 4660          6382798          6382791      2080      1535  ...
# 4661          6382800          6382793      2125      1598  ...
#
#      points_visitor wins_visitor  draws_visitor  losses_visitor  gf_visitor  \
# 4657             40          9.0           13.0            15.0          35
# 4658             41         11.0            8.0            18.0          35
# 4659             58         16.0           10.0            11.0          39
# 4660             62         18.0            8.0            11.0          41
# 4661             37          8.0           13.0            16.0          32
#
#      ga_visitor  avg_visitor  pos_visitor  form_visitor  match_winner
# 4657         42         -7.0           19         lddww             0
# 4658         43         -8.0           18         wlwdd             0
# 4659         34          5.0            6         wlwww             2
# 4660         31         10.0            4         wldwd             1
# 4661         49        -17.0           21         lllld             0
#
# [5 rows x 36 columns]

# %%
df.columns
# Out:
# Index(['match_id', 'year', 'round', 'local', 'visitor', 'league_id',
#        'team1_id_season', 'team2_id_season', 'team1_id', 'team2_id',
#        'local_abbr', 'visitor_abbr', 'division', 'local_goals',
#        'visitor_goals', 'result', 'winner', 'points_local', 'wins_local',
#        'draws_local', 'losses_local', 'gf_local', 'ga_local', 'avg_local',
#        'pos_local', 'form_local', 'points_visitor', 'wins_visitor',
#        'draws_visitor', 'losses_visitor', 'gf_visitor', 'ga_visitor',
#        'avg_visitor', 'pos_visitor', 'form_visitor', 'match_winner'],
#       dtype='object')

# %% [markdown]
# #### Results a Round before

# %%
def prev1roundlocal(col):
    if col['form_local'][0] == 'w':
        return 3
    if col['form_local'][0] == 'd':
        return 1
    if col['form_local'][0] == 'l':
        return 0

df['round-1_local'] = df.apply(lambda col: prev1roundlocal (col),axis=1)
df['round-1_local']
# Out:
# 0       1
# 1       1
# 2       3
# 3       3
# 4       1
#        ..
# 4657    0
# 4658    3
# 4659    3
# 4660    3
# 4661    0
# Name: round-1_local, Length: 4662, dtype: int64

# %%
df['form_local']
# Out:
# 0           d
# 1           d
# 2           w
# 3           w
# 4           d
#         ...
# 4657    ldwld
# 4658    wddwl
# 4659    wwdld
# 4660    wlddl
# 4661    llldd
# Name: form_local, Length: 4662, dtype: object

# %%
def prev1roundvisitor(col):
    if col['form_visitor'][0] == 'w':
        return 3
    if col['form_visitor'][0] == 'd':
        return 1
    if col['form_visitor'][0] == 'l':
        return 0

df['round-1_visitor'] = df.apply(lambda col: prev1roundlocal (col), axis=1)
df['round-1_visitor'].tail()
# Out:
# 4657    0
# 4658    3
# 4659    3
# 4660    3
# 4661    0
# Name: round-1_visitor, dtype: int64

# %%
df.head(5)
# Out:
#    match_id  year  round        local         visitor  league_id  \
# 0     37467  2016      2   Villarreal        Espanyol      15373
# 1     37471  2016      2  R. Sociedad   Real Sporting      15373
# 2     37463  2016      2    Barcelona          Málaga      15373
# 3     37457  2016      2        Celta  Rayo Vallecano      15373
# 4     37469  2016      2  Real Madrid      Real Betis      15373
#
#    team1_id_season  team2_id_season  team1_id  team2_id  ... draws_visitor  \
# 0           214625           214629      2716       998  ...           0.0
# 1           214631           214619      2120      2125  ...           1.0
# 2           214620           214628       429      1617  ...           1.0
# 3           214627           214630       712      2080  ...           1.0
# 4           214621           214618      2107       486  ...           1.0
#
#   losses_visitor  gf_visitor  ga_visitor  avg_visitor pos_visitor  \
# 0            0.0           1           0          1.0           5
# 1            0.0           0           0          0.0          13
# 2            0.0           0           0          0.0           9
# 3            0.0           0           0          0.0          11
# 4            0.0           1           1          0.0           6
#
#    form_visitor  match_winner  round-1_local  round-1_visitor
# 0             w             0              1                1
# 1             d             1              1                1
# 2             d             0              3                3
# 3             d             0              3                3
# 4             d             0              1                1
#
# [5 rows x 38 columns]

# %% [markdown]
# In order to extract information of previous rounds from columns 'form_local' & 'form_visitor' is necessary to put into the same length the strings from each row in this colums. We will fill the spaces with 'n' from none.

# %%
max_length = df.form_local.map(len).max()
df.form_local = df.form_local.apply(lambda x: x + 'n'*(max_length - len(x)))
df['form_local']
# Out:
# 0       dnnnn
# 1       dnnnn
# 2       wnnnn
# 3       wnnnn
# 4       dnnnn
#         ...
# 4657    ldwld
# 4658    wddwl
# 4659    wwdld
# 4660    wlddl
# 4661    llldd
# Name: form_local, Length: 4662, dtype: object

# %%
df.form_visitor = df.form_visitor.apply(lambda x: x + 'n'*(max_length - len(x)))
df['form_visitor']
# Out:
# 0       wnnnn
# 1       dnnnn
# 2       dnnnn
# 3       dnnnn
# 4       dnnnn
#         ...
# 4657    lddww
# 4658    wlwdd
# 4659    wlwww
# 4660    wldwd
# 4661    lllld
# Name: form_visitor, Length: 4662, dtype: object

# %% [markdown]
# We create new columns assigning points to the home and away teams according to their results in the last matches. In order not to confuse the model, when we do not have information about the result of the round in question (this happens in the first rounds), we will assign an indicative value to the coefficient, different from 0, 1 and 3, so as not to confuse the lack of information with wins, draws or defeats.

# %% [markdown]
# #### Results 2 Rounds before

# %%
def prevroundlocal(col, round):
    if col['form_local'][round] == 'w':
        return 3
    if col['form_local'][round] == 'd':
        return 1
    if col['form_local'][round] == 'l':
        return 0
    if col['form_local'][1] == 'n':
        return 1.5

df['round-2_local'] = df.apply(lambda col: prevroundlocal (col, 2),axis=1)
df['round-3_local'] = df.apply(lambda col: prevroundlocal (col, 3),axis=1)

# %%
df.head()
# Out:
#    match_id  year  round        local         visitor  league_id  \
# 0     37467  2016      2   Villarreal        Espanyol      15373
# 1     37471  2016      2  R. Sociedad   Real Sporting      15373
# 2     37463  2016      2    Barcelona          Málaga      15373
# 3     37457  2016      2        Celta  Rayo Vallecano      15373
# 4     37469  2016      2  Real Madrid      Real Betis      15373
#
#    team1_id_season  team2_id_season  team1_id  team2_id  ... gf_visitor  \
# 0           214625           214629      2716       998  ...          1
# 1           214631           214619      2120      2125  ...          0
# 2           214620           214628       429      1617  ...          0
# 3           214627           214630       712      2080  ...          0
# 4           214621           214618      2107       486  ...          1
#
#   ga_visitor  avg_visitor  pos_visitor  form_visitor match_winner  \
# 0          0          1.0            5         wnnnn            0
# 1          0          0.0           13         dnnnn            1
# 2          0          0.0            9         dnnnn            0
# 3          0          0.0           11         dnnnn            0
# 4          1          0.0            6         dnnnn            0
#
#    round-1_local  round-1_visitor  round-2_local  round-3_local
# 0              1                1            1.5            1.5
# 1              1                1            1.5            1.5
# 2              3                3            1.5            1.5
# 3              3                3            1.5            1.5
# 4              1                1            1.5            1.5
#
# [5 rows x 40 columns]

# %%
def prev2roundlocal(col):
    if col['form_local'][1] == 'n':
        return 1.5
    if col['form_local'][1] == 'w':
        return 3
    if col['form_local'][1] == 'd':
        return 1
    if col['form_local'][1] == 'l':
        return 0

df['round-2_local'] = df.apply(lambda col: prev2roundlocal (col),axis=1)
df['round-2_local'].head()
# Out:
# 0    1.5
# 1    1.5
# 2    1.5
# 3    1.5
# 4    1.5
# Name: round-2_local, dtype: float64

# %%
def prev2roundvisitor(col):
    if col['form_visitor'][1] == 'n':
        return 1.5
    if col['form_visitor'][1] == 'w':
        return 3
    if col['form_visitor'][1] == 'd':
        return 1
    if col['form_visitor'][1] == 'l':
        return 0

df['round-2_visitor'] = df.apply(lambda col: prev2roundvisitor (col),axis=1)
df['round-2_visitor'].tail()
# Out:
# 4657    1.0
# 4658    0.0
# 4659    0.0
# 4660    0.0
# 4661    0.0
# Name: round-2_visitor, dtype: float64

# %% [markdown]
# #### Results 3 Rounds before

# %%
def prev3roundlocal(col):
    if col['form_local'][2] == 'n':
        return 1.5
    if col['form_local'][2] == 'w':
        return 3
    if col['form_local'][2] == 'd':
        return 1
    if col['form_local'][2] == 'l':
        return 0

df['round-3_local'] = df.apply(lambda col: prev3roundlocal (col),axis=1)
df['round-3_local'].head()
# Out:
# 0    1.5
# 1    1.5
# 2    1.5
# 3    1.5
# 4    1.5
# Name: round-3_local, dtype: float64

# %%
def prev3roundvisitor(col):
    if col['form_visitor'][2] == 'n':
        return 1.5
    if col['form_visitor'][2] == 'w':
        return 3
    if col['form_visitor'][2] == 'd':
        return 1
    if col['form_visitor'][2] == 'l':
        return 0

df['round-3_visitor'] = df.apply(lambda col: prev3roundvisitor (col),axis=1)
df['round-3_visitor'].tail()
# Out:
# 4657    1.0
# 4658    3.0
# 4659    3.0
# 4660    1.0
# 4661    0.0
# Name: round-3_visitor, dtype: float64

# %% [markdown]
# #### Results 4 Rounds before

# %%
def prev4roundlocal(col):
    if col['form_local'][3] == 'n':
        return 1.5
    if col['form_local'][3] == 'w':
        return 3
    if col['form_local'][3] == 'd':
        return 1
    if col['form_local'][3] == 'l':
        return 0

df['round-4_local'] = df.apply(lambda col: prev4roundlocal (col),axis=1)
df['round-4_local'].head()
# Out:
# 0    1.5
# 1    1.5
# 2    1.5
# 3    1.5
# 4    1.5
# Name: round-4_local, dtype: float64

# %%
def prev4roundvisitor(col):
    if col['form_visitor'][3] == 'n':
        return 1.5
    if col['form_visitor'][3] == 'w':
        return 3
    if col['form_visitor'][3] == 'd':
        return 1
    if col['form_visitor'][3] == 'l':
        return 0

df['round-4_visitor'] = df.apply(lambda col: prev4roundvisitor (col),axis=1)
df['round-4_visitor'].tail()
# Out:
# 4657    3.0
# 4658    1.0
# 4659    3.0
# 4660    3.0
# 4661    0.0
# Name: round-4_visitor, dtype: float64

# %% [markdown]
# ##### Results 5 Rounds before

# %%
def prev5roundlocal(col):
    if col['form_local'][4] == 'n':
        return 1.5
    if col['form_local'][4] == 'w':
        return 3
    if col['form_local'][4] == 'd':
        return 1
    if col['form_local'][4] == 'l':
        return 0

df['round-5_local'] = df.apply(lambda col: prev5roundlocal (col),axis=1)
df['round-5_local'].head()
# Out:
# 0    1.5
# 1    1.5
# 2    1.5
# 3    1.5
# 4    1.5
# Name: round-5_local, dtype: float64

# %%
def prev5roundvisitor(col):
    if col['form_visitor'][4] == 'n':
        return 1.5
    if col['form_visitor'][4] == 'w':
        return 3
    if col['form_visitor'][4] == 'd':
        return 1
    if col['form_visitor'][4] == 'l':
        return 0

df['round-5_visitor'] = df.apply(lambda col: prev5roundvisitor (col),axis=1)
df['round-5_visitor'].tail()
# Out:
# 4657    3.0
# 4658    1.0
# 4659    3.0
# 4660    1.0
# 4661    1.0
# Name: round-5_visitor, dtype: float64

# %%
df.head(5)
# Out:
#    match_id  year  round        local         visitor  league_id  \
# 0     37467  2016      2   Villarreal        Espanyol      15373
# 1     37471  2016      2  R. Sociedad   Real Sporting      15373
# 2     37463  2016      2    Barcelona          Málaga      15373
# 3     37457  2016      2        Celta  Rayo Vallecano      15373
# 4     37469  2016      2  Real Madrid      Real Betis      15373
#
#    team1_id_season  team2_id_season  team1_id  team2_id  ... round-1_local  \
# 0           214625           214629      2716       998  ...             1
# 1           214631           214619      2120      2125  ...             1
# 2           214620           214628       429      1617  ...             3
# 3           214627           214630       712      2080  ...             3
# 4           214621           214618      2107       486  ...             1
#
#   round-1_visitor  round-2_local  round-2_visitor  round-3_local  \
# 0               1            1.5              1.5            1.5
# 1               1            1.5              1.5            1.5
# 2               3            1.5              1.5            1.5
# 3               3            1.5              1.5            1.5
# 4               1            1.5              1.5            1.5
#
#   round-3_visitor  round-4_local  round-4_visitor  round-5_local  \
# 0             1.5            1.5              1.5            1.5
# 1             1.5            1.5              1.5            1.5
# 2             1.5            1.5              1.5            1.5
# 3             1.5            1.5              1.5            1.5
# 4             1.5            1.5              1.5            1.5
#
#    round-5_visitor
# 0              1.5
# 1              1.5
# 2              1.5
# 3              1.5
# 4              1.5
#
# [5 rows x 46 columns]

# %% [markdown]
# #### Coefficients of points accumulated in the last rounds

# %% [markdown]
# Creating new columns with the points accumulated int he last rounds from each team.

# %%
df['pts_last2_local'] = df.apply(lambda x: x['round-1_local'] + x['round-2_local'] + x['round-3_local'], axis=1)
df['pts_last2_local'].head()
# Out:
# 0    4.0
# 1    4.0
# 2    6.0
# 3    6.0
# 4    4.0
# Name: pts_last2_local, dtype: float64

# %%
print(df['round-1_local'], df['round-2_local'])
# Out:
# 0       1
# 1       1
# 2       3
# 3       3
# 4       1
#        ..
# 4657    0
# 4658    3
# 4659    3
# 4660    3
# 4661    0
# Name: round-1_local, Length: 4662, dtype: int64 0       1.5
# 1       1.5
# 2       1.5
# 3       1.5
# 4       1.5
#        ...
# 4657    1.0
# 4658    1.0
# 4659    3.0
# 4660    0.0
# 4661    0.0
# Name: round-2_local, Length: 4662, dtype: float64

# %%
df['pts_last3_local'] = df.apply(lambda x: x['round-1_local'] + x['round-2_local'] + x['round-3_local'] , axis=1)
df['pts_last4_local'] = df.apply(lambda x: x['round-1_local'] + x['round-2_local'] + x['round-3_local'] + x['round-4_local'] , axis=1)
df['pts_last5_local'] = df.apply(lambda x: x['round-1_local'] + x['round-2_local'] + x['round-3_local'] + x['round-4_local'] + x['round-5_local'], axis=1)
df['pts_last2_visitor'] = df.apply(lambda x: x['round-1_visitor'] + x['round-2_visitor'] , axis=1)
df['pts_last3_visitor'] = df.apply(lambda x: x['round-1_visitor'] + x['round-2_visitor'] + x['round-3_visitor']  , axis=1)
df['pts_last4_visitor'] = df.apply(lambda x: x['round-1_visitor'] + x['round-2_visitor'] + x['round-3_visitor'] + x['round-4_visitor'] , axis=1)
df['pts_last5_visitor'] = df.apply(lambda x: x['round-1_visitor'] + x['round-2_visitor'] + x['round-3_visitor'] + x['round-4_visitor'] + x['round-5_visitor'], axis=1)

# %%
df.tail(10)
# Out:
#       match_id  year  round           local       visitor  league_id  \
# 4652     91108  2021     38    Ponferradina      Albacete      57314
# 4653     91113  2021     38   Real Zaragoza      Espanyol      57314
# 4654     91103  2021     38        Alcorcón    Las Palmas      57314
# 4655     91106  2021     38          Málaga      Mallorca      57314
# 4656     91107  2021     38        Mirandés   Fuenlabrada      57314
# 4657     91110  2021     38     Real Oviedo      Sabadell      57314
# 4658     91104  2021     38    FC Cartagena  CD Castellón      57314
# 4659     91112  2021     38     UD Logroñés        Girona      57314
# 4660     91109  2021     38  Rayo Vallecano       Leganés      57314
# 4661     91105  2021     38   Real Sporting          Lugo      57314
#
#       team1_id_season  team2_id_season  team1_id  team2_id  ... round-5_local  \
# 4652          6382797          6382785      3287       140  ...           0.0
# 4653          6390092          6382789      2136       998  ...           1.0
# 4654          6382786          6382790        64      2563  ...           3.0
# 4655          6382794          6382795      1617      1623  ...           0.0
# 4656          6382796          6387869      1699      1179  ...           0.0
# 4657          6382799          6382802      2115      2198  ...           1.0
# 4658          6382787          6382788       643       673  ...           0.0
# 4659          6382792          6391868      1578      1236  ...           1.0
# 4660          6382798          6382791      2080      1535  ...           0.0
# 4661          6382800          6382793      2125      1598  ...           1.0
#
#      round-5_visitor  pts_last2_local  pts_last3_local  pts_last4_local  \
# 4652             0.0              2.0              2.0              5.0
# 4653             3.0              6.0              6.0              7.0
# 4654             3.0              6.0              6.0              6.0
# 4655             3.0              7.0              7.0              7.0
# 4656             3.0              4.0              4.0              5.0
# 4657             3.0              4.0              4.0              4.0
# 4658             1.0              5.0              5.0              8.0
# 4659             3.0              7.0              7.0              7.0
# 4660             1.0              4.0              4.0              5.0
# 4661             1.0              0.0              0.0              1.0
#
#      pts_last5_local  pts_last2_visitor  pts_last3_visitor  pts_last4_visitor  \
# 4652             5.0                0.0                3.0                4.0
# 4653             8.0                6.0                7.0               10.0
# 4654             9.0                1.0                2.0                2.0
# 4655             7.0                6.0                6.0                6.0
# 4656             5.0                4.0                5.0                8.0
# 4657             5.0                1.0                2.0                5.0
# 4658             8.0                3.0                6.0                7.0
# 4659             8.0                3.0                6.0                9.0
# 4660             5.0                3.0                4.0                7.0
# 4661             2.0                0.0                0.0                0.0
#
#       pts_last5_visitor
# 4652                4.0
# 4653               13.0
# 4654                5.0
# 4655                9.0
# 4656               11.0
# 4657                8.0
# 4658                8.0
# 4659               12.0
# 4660                8.0
# 4661                1.0
#
# [10 rows x 54 columns]

# %% [markdown]
# #### Diferencia de puntos y de avg

# %%
df['pts_difference'] = df.apply(lambda x: x['points_local'] - x['points_visitor'] , axis=1)
df['avg_difference'] = df.apply(lambda x: x['avg_local'] - x['avg_visitor'] , axis=1)

# %%
df.head(5)
# Out:
#    match_id  year  round        local         visitor  league_id  \
# 0     37467  2016      2   Villarreal        Espanyol      15373
# 1     37471  2016      2  R. Sociedad   Real Sporting      15373
# 2     37463  2016      2    Barcelona          Málaga      15373
# 3     37457  2016      2        Celta  Rayo Vallecano      15373
# 4     37469  2016      2  Real Madrid      Real Betis      15373
#
#    team1_id_season  team2_id_season  team1_id  team2_id  ... pts_last2_local  \
# 0           214625           214629      2716       998  ...             4.0
# 1           214631           214619      2120      2125  ...             4.0
# 2           214620           214628       429      1617  ...             6.0
# 3           214627           214630       712      2080  ...             6.0
# 4           214621           214618      2107       486  ...             4.0
#
#   pts_last3_local  pts_last4_local  pts_last5_local  pts_last2_visitor  \
# 0             4.0              5.5              7.0                2.5
# 1             4.0              5.5              7.0                2.5
# 2             6.0              7.5              9.0                4.5
# 3             6.0              7.5              9.0                4.5
# 4             4.0              5.5              7.0                2.5
#
#   pts_last3_visitor  pts_last4_visitor  pts_last5_visitor  pts_difference  \
# 0               4.0                5.5                7.0              -2
# 1               4.0                5.5                7.0               0
# 2               6.0                7.5                9.0               2
# 3               6.0                7.5                9.0               2
# 4               4.0                5.5                7.0               0
#
#    avg_difference
# 0            -1.0
# 1             0.0
# 2             1.0
# 3             1.0
# 4             0.0
#
# [5 rows x 56 columns]

# %%
df.columns
# Out:
# Index(['match_id', 'year', 'round', 'local', 'visitor', 'league_id',
#        'team1_id_season', 'team2_id_season', 'team1_id', 'team2_id',
#        'local_abbr', 'visitor_abbr', 'division', 'local_goals',
#        'visitor_goals', 'result', 'winner', 'points_local', 'wins_local',
#        'draws_local', 'losses_local', 'gf_local', 'ga_local', 'avg_local',
#        'pos_local', 'form_local', 'points_visitor', 'wins_visitor',
#        'draws_visitor', 'losses_visitor', 'gf_visitor', 'ga_visitor',
#        'avg_visitor', 'pos_visitor', 'form_visitor', 'match_winner',
#        'round-1_local', 'round-1_visitor', 'round-2_local', 'round-2_visitor',
#        'round-3_local', 'round-3_visitor', 'round-4_local', 'round-4_visitor',
#        'round-5_local', 'round-5_visitor', 'pts_last2_local',
#        'pts_last3_local', 'pts_last4_local', 'pts_last5_local',
#        'pts_last2_visitor', 'pts_last3_visitor', 'pts_last4_visitor',
#        'pts_last5_visitor', 'pts_difference', 'avg_difference'],
#       dtype='object')

# %% [markdown]
# ### Introducing categorical input variable
#
# We want to enter the id of each team as an input variable (categorical). In this way the model takes into account the behaviour of the teams in previous seasons (historical trend of the team's results).(teams ids: team1_id_season y team1_id)

# %%
df.head(5)
# Out:
#    match_id  year  round        local         visitor  league_id  \
# 0     37467  2016      2   Villarreal        Espanyol      15373
# 1     37471  2016      2  R. Sociedad   Real Sporting      15373
# 2     37463  2016      2    Barcelona          Málaga      15373
# 3     37457  2016      2        Celta  Rayo Vallecano      15373
# 4     37469  2016      2  Real Madrid      Real Betis      15373
#
#    team1_id_season  team2_id_season  team1_id  team2_id  ... pts_last2_local  \
# 0           214625           214629      2716       998  ...             4.0
# 1           214631           214619      2120      2125  ...             4.0
# 2           214620           214628       429      1617  ...             6.0
# 3           214627           214630       712      2080  ...             6.0
# 4           214621           214618      2107       486  ...             4.0
#
#   pts_last3_local  pts_last4_local  pts_last5_local  pts_last2_visitor  \
# 0             4.0              5.5              7.0                2.5
# 1             4.0              5.5              7.0                2.5
# 2             6.0              7.5              9.0                4.5
# 3             6.0              7.5              9.0                4.5
# 4             4.0              5.5              7.0                2.5
#
#   pts_last3_visitor  pts_last4_visitor  pts_last5_visitor  pts_difference  \
# 0               4.0                5.5                7.0              -2
# 1               4.0                5.5                7.0               0
# 2               6.0                7.5                9.0               2
# 3               6.0                7.5                9.0               2
# 4               4.0                5.5                7.0               0
#
#    avg_difference
# 0            -1.0
# 1             0.0
# 2             1.0
# 3             1.0
# 4             0.0
#
# [5 rows x 56 columns]

# %%
local_encoded = pd.get_dummies(df['local'])
local_encoded.columns = [item + "_local" for item in local_encoded.columns]

visitor_encoded = pd.get_dummies(df['visitor'])
visitor_encoded.columns = [item + "_visitor" for item in visitor_encoded.columns]

# %%
df_input = df.copy()

# %%
df_input = df_input.join(local_encoded)
df_input = df_input.join(visitor_encoded)

# %%
winner = df_input.pop('match_winner')
df_input.insert(df_input.shape[1], 'match_winner', winner)

# %%
df_input[['local_abbr', 'visitor_abbr', 'division', 'local_goals',
       'visitor_goals', 'result', 'winner', 'points_local', 'wins_local',
       'draws_local', 'losses_local', 'gf_local', 'ga_local', 'avg_local',
       'pos_local', 'form_local', 'points_visitor', 'wins_visitor',
       'draws_visitor']]
# Out:
#      local_abbr visitor_abbr  division  local_goals  visitor_goals result  \
# 0           VIL          ESP         1            3              1    3-1
# 1           RSO          SPO         1            0              0    0-0
# 2           FCB          MAL         1            1              0    1-0
# 3           CEL          RAY         1            3              0    3-0
# 4           RMA          BET         1            5              0    5-0
# ...         ...          ...       ...          ...            ...    ...
# 4657        ROV          SAB         2            2              1    2-1
# 4658        CAR          CAS         2            1              0    1-0
# 4659        UDL          GIR         2            1              4    1-4
# 4660        RAY          LEG         2            1              1    1-1
# 4661        SPO          LUG         2            1              0    1-0
#
#        winner  points_local  wins_local  draws_local  losses_local  gf_local  \
# 0      214625             1         0.0          1.0           0.0         1
# 1           0             1         0.0          1.0           0.0         0
# 2      214620             3         1.0          0.0           0.0         1
# 3      214627             3         1.0          0.0           0.0         2
# 4      214621             1         0.0          1.0           0.0         0
# ...       ...           ...         ...          ...           ...       ...
# 4657  6382799            44         9.0         17.0          11.0        38
# 4658  6382787            39         9.0         12.0          16.0        36
# 4659  6391868            41        10.0         11.0          16.0        25
# 4660        0            57        16.0          9.0          12.0        43
# 4661  6382800            58        15.0         13.0           9.0        35
#
#       ga_local  avg_local  pos_local form_local  points_visitor  wins_visitor  \
# 0            1        0.0          7      dnnnn               3           1.0
# 1            0        0.0         10      dnnnn               1           0.0
# 2            0        1.0          4      wnnnn               1           0.0
# 3            1        1.0          2      wnnnn               1           0.0
# 4            0        0.0         12      dnnnn               1           0.0
# ...        ...        ...        ...        ...             ...           ...
# 4657        38        0.0         14      ldwld              40           9.0
# 4658        47      -11.0         20      wddwl              41          11.0
# 4659        43      -18.0         17      wwdld              58          16.0
# 4660        36        7.0          7      wlddl              62          18.0
# 4661        25       10.0          5      llldd              37           8.0
#
#       draws_visitor
# 0               0.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ...             ...
# 4657           13.0
# 4658            8.0
# 4659           10.0
# 4660            8.0
# 4661           13.0
#
# [4662 rows x 19 columns]

# %%
remove_columns = ['local', 'visitor', 'league_id', 'team1_id_season', 'team2_id_season', 'team1_id',
               'team2_id', 'local_abbr', 'visitor_abbr', 'local_goals', 'visitor_goals', 'result', 'winner', 
               'form_local', 'form_visitor']
df_ml = df_input[[item for item in df_input.columns if item not in remove_columns]]

# %%
df_ml
# Out:
#       match_id  year  round  division  points_local  wins_local  draws_local  \
# 0        37467  2016      2         1             1         0.0          1.0
# 1        37471  2016      2         1             1         0.0          1.0
# 2        37463  2016      2         1             3         1.0          0.0
# 3        37457  2016      2         1             3         1.0          0.0
# 4        37469  2016      2         1             1         0.0          1.0
# ...        ...   ...    ...       ...           ...         ...          ...
# 4657     91110  2021     38         2            44         9.0         17.0
# 4658     91104  2021     38         2            39         9.0         12.0
# 4659     91112  2021     38         2            41        10.0         11.0
# 4660     91109  2021     38         2            57        16.0          9.0
# 4661     91105  2021     38         2            58        15.0         13.0
#
#       losses_local  gf_local  ga_local  ...  Reus Deportiu_visitor  \
# 0              0.0         1         1  ...                      0
# 1              0.0         0         0  ...                      0
# 2              0.0         1         0  ...                      0
# 3              0.0         2         1  ...                      0
# 4              0.0         0         0  ...                      0
# ...            ...       ...       ...  ...                    ...
# 4657          11.0        38        38  ...                      0
# 4658          16.0        36        47  ...                      0
# 4659          16.0        25        43  ...                      0
# 4660          12.0        43        36  ...                      0
# 4661           9.0        35        25  ...                      0
#
#       Sabadell_visitor  Sevilla_visitor  Sevilla At._visitor  \
# 0                    0                0                    0
# 1                    0                0                    0
# 2                    0                0                    0
# 3                    0                0                    0
# 4                    0                0                    0
# ...                ...              ...                  ...
# 4657                 1                0                    0
# 4658                 0                0                    0
# 4659                 0                0                    0
# 4660                 0                0                    0
# 4661                 0                0                    0
#
#       Tenerife_visitor  UCAM Murcia_visitor  UD Logroñés_visitor  \
# 0                    0                    0                    0
# 1                    0                    0                    0
# 2                    0                    0                    0
# 3                    0                    0                    0
# 4                    0                    0                    0
# ...                ...                  ...                  ...
# 4657                 0                    0                    0
# 4658                 0                    0                    0
# 4659                 0                    0                    0
# 4660                 0                    0                    0
# 4661                 0                    0                    0
#
#       Valencia_visitor  Villarreal_visitor  match_winner
# 0                    0                   0             0
# 1                    0                   0             1
# 2                    0                   0             0
# 3                    0                   0             0
# 4                    0                   0             0
# ...                ...                 ...           ...
# 4657                 0                   0             0
# 4658                 0                   0             0
# 4659                 0                   0             2
# 4660                 0                   0             1
# 4661                 0                   0             0
#
# [4662 rows x 155 columns]

# %%
df_ml.to_excel('featured data.xls')

# %% [markdown]
# ### Logistic Regression

# %%
features = df_ml.values[:, :-1]
target = df_ml.values[:, -1]
X, y = features, target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

model = LogisticRegression(max_iter = 500)
model.fit(X_train_scaled, y_train)

#predictions_lr = model.predict(X_test)

X_test_scaled = scaler.transform(X_test)

y_pred = model.predict(X_test_scaled)

np.mean(y_pred == y_test)
# Out:
# 0.49678800856531047

# %%
target_names = ['Gana Local', 'Empate', 'Gana Visitante']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#     Gana Local       0.54      0.72      0.62       218
#         Empate       0.35      0.24      0.29       131
# Gana Visitante       0.52      0.36      0.43       118
#
#       accuracy                           0.50       467
#      macro avg       0.47      0.44      0.44       467
#   weighted avg       0.48      0.50      0.48       467

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[157,  37,  24],
#        [ 83,  32,  16],
#        [ 52,  23,  43]], dtype=int64)

# %%
prediction_LR = pd.DataFrame([y_pred, y_test]).T
prediction_LR
# Out:
#        0    1
# 0    0.0  0.0
# 1    1.0  1.0
# 2    0.0  2.0
# 3    0.0  0.0
# 4    0.0  0.0
# ..   ...  ...
# 462  0.0  1.0
# 463  0.0  1.0
# 464  2.0  2.0
# 465  1.0  1.0
# 466  2.0  1.0
#
# [467 rows x 2 columns]

# %%
prediction_LR = prediction_LR.rename(columns={0:'pred', 1:'test'})

# %%
def success(col):
    if col[0] == col[1]:
        return 1
    else:
        return 0
# Out:
#      pred  test  success
# 462   0.0   1.0        0
# 463   0.0   1.0        0
# 464   2.0   2.0        1
# 465   1.0   1.0        1
# 466   2.0   1.0        0

# %%
prediction_LR['success'] = prediction_LR.apply(lambda col: success (col),axis=1)
prediction_LR.tail()

# %%
prediction_LR.to_excel('LogisticRegression prediction.xls')

# %% [markdown]
# ### Decision Tree

# %%
features = df_ml.values[:, :-1]
target = df_ml.values[:, -1]
X, y = features, target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=30)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

model = DecisionTreeClassifier()
model.fit(X_train_scaled, y_train)


#predictions_dt = model.predict(X_test)

X_test_scaled = scaler.transform(X_test)

y_pred = model.predict(X_test_scaled)

np.mean(y_pred == y_test)
# Out:
# 0.43254817987152033

# %%
target_names = ['Gana Local', 'Empate', 'Gana Visitante']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#     Gana Local       0.55      0.51      0.53       218
#         Empate       0.34      0.35      0.35       131
# Gana Visitante       0.34      0.37      0.35       118
#
#       accuracy                           0.43       467
#      macro avg       0.41      0.41      0.41       467
#   weighted avg       0.44      0.43      0.44       467

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[157,  37,  24],
#        [ 83,  32,  16],
#        [ 52,  23,  43]], dtype=int64)

# %%
prediction_DT = pd.DataFrame([y_pred, y_test]).T
prediction_DT
# Out:
#        0    1
# 0    0.0  0.0
# 1    1.0  1.0
# 2    0.0  2.0
# 3    0.0  0.0
# 4    0.0  0.0
# ..   ...  ...
# 462  0.0  1.0
# 463  0.0  1.0
# 464  2.0  2.0
# 465  1.0  1.0
# 466  2.0  1.0
#
# [467 rows x 2 columns]

# %%
prediction_DT = prediction_LR.rename(columns={0:'pred', 1:'test'})

# %%
prediction_DT['success'] = prediction_DT.apply(lambda col: success (col),axis=1)
prediction_DT.tail()

# %%
prediction_DT.to_excel('DecissionTree prediction.xls')

# %% [markdown]
# ### Random Forest

# %%
features = df_ml.values[:, :-1]
target = df_ml.values[:, -1]
X, y = features, target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=30)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)


#predictions_rf = model.predict(X_test)

X_test_scaled = scaler.transform(X_test)

y_pred = model.predict(X_test_scaled)

np.mean(y_pred == y_test)
# Out:
# 0.4732334047109208

# %%
target_names = ['Gana Local', 'Empate', 'Gana Visitante']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#     Gana Local       0.51      0.75      0.61       218
#         Empate       0.31      0.18      0.22       131
# Gana Visitante       0.47      0.30      0.36       118
#
#       accuracy                           0.47       467
#      macro avg       0.43      0.41      0.40       467
#   weighted avg       0.44      0.47      0.44       467

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[157,  37,  24],
#        [ 83,  32,  16],
#        [ 52,  23,  43]], dtype=int64)

# %%
prediction_RF = pd.DataFrame([y_pred, y_test]).T
prediction_RF
# Out:
#        0    1
# 0    0.0  0.0
# 1    1.0  1.0
# 2    0.0  2.0
# 3    0.0  0.0
# 4    0.0  0.0
# ..   ...  ...
# 462  0.0  1.0
# 463  0.0  1.0
# 464  2.0  2.0
# 465  1.0  1.0
# 466  2.0  1.0
#
# [467 rows x 2 columns]

# %%
prediction_RF = prediction_RF.rename(columns={0:'pred', 1:'test'})

# %%
prediction_RF['success'] = prediction_RF.apply(lambda col: success (col),axis=1)
prediction_RF.tail()

# %%
prediction_RF.to_excel('RandomForest prediction.xls')

# %% [markdown]
# ### KNeighbors

# %%
from sklearn.neighbors import KNeighborsClassifier
features = df_ml.values[:, :-1]
target = df_ml.values[:, -1]
X, y = features, target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=30)
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

model =KNeighborsClassifier()
model.fit(X_train_scaled, y_train)

#lr.fit(X_train, y_train)
#predictions = lr.predict(X_test)

X_test_scaled = scaler.transform(X_test)

y_pred = model.predict(X_test_scaled)

np.mean(y_pred == y_test)
# Out:
# 0.44325481798715205

# %%
X_test
# Out:
# array([[8.99060e+04, 2.02100e+03, 3.70000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [4.67530e+04, 2.02000e+03, 6.00000e+00, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [4.96164e+05, 2.01800e+03, 1.00000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        ...,
#        [4.96190e+05, 2.01800e+03, 2.00000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [4.67040e+04, 2.02000e+03, 3.00000e+00, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00],
#        [4.96403e+05, 2.01800e+03, 3.00000e+01, ..., 0.00000e+00,
#         0.00000e+00, 0.00000e+00]])

# %%
target_names = ['Gana Local', 'Empate', 'Gana Visitante']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#     Gana Local       0.50      0.66      0.57       218
#         Empate       0.31      0.25      0.28       131
# Gana Visitante       0.43      0.26      0.33       118
#
#       accuracy                           0.44       467
#      macro avg       0.41      0.39      0.39       467
#   weighted avg       0.43      0.44      0.42       467

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[157,  37,  24],
#        [ 83,  32,  16],
#        [ 52,  23,  43]], dtype=int64)

# %%
prediction_KN = pd.DataFrame([y_pred, y_test]).T
prediction_KN
# Out:
#        0    1
# 0    0.0  0.0
# 1    1.0  1.0
# 2    0.0  2.0
# 3    0.0  0.0
# 4    0.0  0.0
# ..   ...  ...
# 462  0.0  1.0
# 463  0.0  1.0
# 464  2.0  2.0
# 465  1.0  1.0
# 466  2.0  1.0
#
# [467 rows x 2 columns]

# %%
prediction_KN = prediction_LR.rename(columns={0:'pred', 1:'test'})

# %%
prediction_KN['success'] = prediction_KN.apply(lambda col: success (col),axis=1)
prediction_KN.tail()

# %%
prediction_KN.to_excel('KNeighbors prediction.xls')

# %%
data_pred = np.squeeze(y_pred)
data_test = np.squeeze(y_test)
data_index = np.squeeze(X_train[0])
plt.plot(data_index, (data_pred, data_test))
prediccion = pd.DataFrame(['y_pred','y_test'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-d71a632b6756> in <module>
#       2 data_test = np.squeeze(y_test)
#       3 data_index = np.squeeze(X_train[0])
# ----> 4 plt.plot(data_index, (data_pred, data_test))
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (154,) and (2, 467)

# %%
df['score_local'] = df['result'].apply(lambda x: x.split("-")[0])
df['score_visitor'] = df['result'].apply(lambda x: x.split("-")[1])
