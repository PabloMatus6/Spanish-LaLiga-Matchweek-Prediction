# %%
import pandas as pd 
import os 
import numpy as np

# %%
df1 = pd.read_csv("season-0910_csv.csv")
df1
# Out:
#      Div        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    SP1  2009-08-29  Real Madrid    La Coruna     3     2   H     2     1
# 1    SP1  2009-08-29     Zaragoza     Tenerife     1     0   H     0     0
# 2    SP1  2009-08-30      Almeria   Valladolid     0     0   D     0     0
# 3    SP1  2009-08-30   Ath Bilbao      Espanol     1     0   H     0     0
# 4    SP1  2009-08-30       Malaga   Ath Madrid     3     0   H     1     0
# ..   ...         ...          ...          ...   ...   ...  ..   ...   ...
# 375  SP1  2010-05-16    Barcelona   Valladolid     4     0   H     2     0
# 376  SP1  2010-05-16       Malaga  Real Madrid     1     1   D     1     0
# 377  SP1  2010-05-16      Osasuna        Xerez     1     1   D     0     0
# 378  SP1  2010-05-16    Santander     Sp Gijon     2     0   H     1     0
# 379  SP1  2010-05-16     Valencia     Tenerife     1     0   H     0     0
#
# ...

# %%
df1.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY',
#        'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'GBH',
#        'GBD', 'GBA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'SBH', 'SBD',
#        'SBA', 'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA',
#        'BSH', 'BSD', 'BSA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
#        'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA',
#        'BbAvAHA'],
#       dtype='object')

# %% [markdown]
# You can find the meaning of each column on this link: https://www.football-data.co.uk/notes.txt

# %%
df2 = pd.read_csv("season-1819_csv.csv")
df2
# Out:
#      Div        Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0    SP1  17/08/2018        Betis     Levante     0     3   A     0     1   A
# 1    SP1  17/08/2018       Girona  Valladolid     0     0   D     0     0   D
# 2    SP1  18/08/2018    Barcelona      Alaves     3     0   H     0     0   D
# 3    SP1  18/08/2018        Celta     Espanol     1     1   D     0     1   A
# 4    SP1  18/08/2018   Villarreal    Sociedad     1     2   A     1     1   D
# ..   ...         ...          ...         ...   ...   ...  ..   ...   ...  ..
# 375  SP1  18/05/2019      Levante  Ath Madrid     2     2   D     2     0   H
# 376  SP1  18/05/2019      Sevilla  Ath Bilbao     2     0   H     1     0   H
# 377  SP1  18/05/2019   Valladolid    Valencia     0     2   A     0     1   A
# 378  SP1  19/05/2019        Eibar   Barcelona     2     2   D     2     2   D
# 379  SP1  19/05/2019  Real Madrid       Betis     0     2   A     0     0   D
#
# ...

# %%
df2.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY',
#        'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH',
#        'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD',
#        'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA',
#        'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5', 'BbAH', 'BbAHh',
#        'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA', 'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')
